# %% [markdown]
# ## Requirement 1: Stochatic Environment

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# Out:
# c:\Users\39327\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\39327\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# c:\Users\39327\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ### Stochastic Pricing Environment

# %%
class StochasticPricingEnvironment:
    def __init__(self, model='linear', alpha=None, beta=None):
        self.model = model
        self.alpha = alpha
        self.beta = beta
        np.random.seed(42)


    # given settled price and number customer
    # returns a sample of number of sale and profit
    def round(self, price_t, n_costumer_t):
        # number of sale at time t
        number_sale_t = np.random.binomial(n_costumer_t, StochasticPricingEnvironment.generate_probability(self.model, self.alpha, self.beta, price_t))

        return number_sale_t

    # takes as input the selling price -> [0,1]
    # return as output the probability of selling -> [0,1]
    @staticmethod
    def generate_probability(model, a, b, price):
        def isNotNone(s,d):
            if s is None:
                return d
            else:
                return s
        global purchase_probabilities
        if model == 'linear':
            alpha = isNotNone(a, 1) # Intercept
            beta = isNotNone(b, -1)  # Slope
            purchase_probabilities = alpha + beta * price
            
        elif model == 'logistic':
            alpha = isNotNone(a, 0)
            beta = isNotNone(b, -5)
            purchase_probabilities = 1 / (1 + np.exp(-(alpha + beta * price)))
            
        elif model == 'probit':
            alpha = isNotNone(a, 0)
            beta = isNotNone(b, -5)
            purchase_probabilities = norm.cdf(alpha + beta * price)
            
        elif model == 'KERNEL':
            purchase_probabilities = np.abs(np.sin(2 * np.pi * price) * np.exp(-price * 5) + price * .10) + .1

        return purchase_probabilities

# %% [markdown]
# ### Pricing Agent : Gaussian Process Agent with RBF kernel and UCB algorithm

# %%
# Radial Basis Function Kernel
class RBFGaussianProcess:
    def __init__(self, scale=1, reg=1e-2):
        self.scale = scale 
        self.reg = reg
        self.k_xx_inv = None

    def rbf_kernel_incr_inv(self, B, C, D):
        temp = np.linalg.inv(D - C @ self.k_xx_inv @ B)
        block1 = self.k_xx_inv + self.k_xx_inv @ B @ temp @ C @ self.k_xx_inv
        block2 = - self.k_xx_inv @ B @ temp
        block3 = - temp @ C @ self.k_xx_inv
        block4 = temp
        res1 = np.concatenate((block1, block2), axis=1)
        res2 = np.concatenate((block3, block4), axis=1)
        res = np.concatenate((res1, res2), axis=0)
        return res

    def rbf_kernel(self, a, b):
        a_ = a.reshape(-1, 1)
        b_ = b.reshape(-1, 1)
        output = -1 * np.ones((a_.shape[0], b_.shape[0]))
        for i in range(a_.shape[0]):
            output[i, :] = np.power(a_[i] - b_, 2).ravel()
        return np.exp(-self.scale * output)
    
    def fit(self, x=np.array([]), y=np.array([])):
        x,y = np.array(x),np.array(y)
        if self.k_xx_inv is None:
            self.y = y.reshape(-1,1)
            self.x = x.reshape(-1,1)
            k_xx = self.rbf_kernel(self.x, self.x) + self.reg * np.eye(self.x.shape[0])
            self.k_xx_inv = np.linalg.inv(k_xx)
        else:
            B = self.rbf_kernel(self.x, x)
            self.x = np.vstack((self.x, x))
            self.y = np.vstack((self.y, y))
            self.k_xx_inv = self.rbf_kernel_incr_inv(B, B.T, np.array([1 + self.reg]))

        return self

    def predict(self, x_predict):
        k = self.rbf_kernel(x_predict, self.x)

        mu_hat = k @ self.k_xx_inv @ self.y
        sigma_hat = 1 - np.diag(k @ self.k_xx_inv @ k.T)

        return mu_hat.ravel(), sigma_hat.ravel()

# %%
class GPUCBAgent:
    def __init__(self, T, minimum_price=0, maximum_price=1, scale=0.1, discretization=None):
        self.T = T
        if(discretization is None):
            # discretization prescribed by theory
            epsilon = T**(-0.33)
            discretization = int(1/epsilon)
        self.minimum_price = minimum_price
        self.maximum_price = maximum_price
        self.arms = np.linspace(minimum_price, maximum_price, discretization)
        self.N_pulls = np.zeros(discretization)
        self.average_bidding_costs = np.zeros(discretization)
        self.average_customer_percentages = np.ones(discretization)
        self.gp = RBFGaussianProcess(scale=scale).fit()
        self.a_t = None
        self.action_hist = []
        self.reward_hist = []
        self.mu_t = np.zeros(discretization)
        self.sigma_t = np.zeros(discretization)
        self.gamma = lambda t: np.log(t+1)**2 
        self.beta = lambda t: 1 + 0.5*np.sqrt(2 * (self.gamma(t) + 1 + np.log(T)))
        self.t = 0
    
    def pull_arm(self, verbose=False):
        # play every arm at least once
        if self.t < len(self.arms):
            self.a_t = self.t
            return self.arms[self.a_t],1,self.average_bidding_costs[self.a_t]
        else:
            # averages of GP  +  estimation uncertainty  -> purchase probability
            self.mu_t, self.sigma_t = self.gp.predict(self.arms) 
            purchase_probabilities = self.mu_t + self.beta(self.t) * self.sigma_t
            # estimated profit per customer of each price
            estimated_profits_per_customer = purchase_probabilities * self.arms - self.average_bidding_costs
            # estimated total profit of each price
            ucbs = estimated_profits_per_customer * self.average_customer_percentages
            self.a_t = np.argmax(ucbs)
            if(verbose):
                print(purchase_probabilities)
                print(self.arms - self.average_bidding_costs)
                print(estimated_profits_per_customer)
                print(self.average_customer_percentages)
                print(ucbs)
            return self.arms[self.a_t], purchase_probabilities[self.a_t], self.average_bidding_costs[self.a_t]
    
    def update(self, n_sales_t, n_customers_t, bidding_cost_per_customer_t=0, customer_percentage=1):
        self.N_pulls[self.a_t] += 1
        self.average_bidding_costs[self.a_t] += (bidding_cost_per_customer_t - self.average_bidding_costs[self.a_t])/self.N_pulls[self.a_t]
        # probability of winning customers of arm
        # self.average_customer_percentages[self.a_t] += (customer_percentage - self.average_customer_percentages[self.a_t])/self.N_pulls[self.a_t]
        self.average_customer_percentages[self.a_t] = 0.8*self.average_customer_percentages[self.a_t] + 0.2*customer_percentage
        # purchase probability of arm
        estimated_purchase_probability = 0
        if(n_customers_t != 0):
            estimated_purchase_probability = n_sales_t / n_customers_t
        self.gp = self.gp.fit(self.arms[self.a_t], estimated_purchase_probability)
        self.t += 1
        self.action_hist.append(self.arms[self.a_t])
        self.reward_hist.append((self.arms[self.a_t]-self.minimum_price)*n_sales_t - bidding_cost_per_customer_t*n_customers_t)

# %%
# UCB1 agent for performance comparison
class UCB1Agent:
    def __init__(self, T, K=None, range=1):
        if K is None:
            # prescribed by theory
            epsilon = T**(-0.33)
            K = int(1/epsilon)
        self.K = K
        self.T = T
        self.range = range
        self.a_t = None
        self.average_rewards = np.zeros(K)
        self.N_pulls = np.zeros(K)
        self.t = 0
    
    def pull_arm(self):
        if self.t < self.K:
            self.a_t = self.t 
        else:
            ucbs = self.average_rewards + self.range*np.sqrt(2*np.log(self.T)/self.N_pulls)
            self.a_t = np.argmax(ucbs)
        return self.a_t
    
    def update(self, r_t, verbose = False):
        if verbose:
            print(f'updating arm {self.a_t} with reward {r_t} average reward : {self.average_rewards[self.a_t]:.2f} -> {(self.average_rewards[self.a_t] + (r_t - self.average_rewards[self.a_t])/(self.N_pulls[self.a_t]+1)):.2f}')
        self.N_pulls[self.a_t] += 1
        self.average_rewards[self.a_t] += (r_t - self.average_rewards[self.a_t])/self.N_pulls[self.a_t]
        self.t += 1

# %% [markdown]
# ### Bidding Environment

# %%
class SecondPriceAuction:
    def __init__(self, ctrs):
        # ctr = click though rate = lambda * q
        self.ctrs = ctrs
        self.n_adv = len(self.ctrs)
    
    def get_winners(self, bids):
        # sort not by bids, but estimated values
        adv_values = self.ctrs*bids
        adv_ranking = np.argsort(adv_values)
        winner = adv_ranking[-1]
        return winner, adv_values
    
    def get_payments_per_click(self, winners, values, bids):
        adv_ranking = np.argsort(values)
        second = adv_ranking[-2]
        payment = values[second]/self.ctrs[winners]
        return payment.round(2)
    
    def round(self, bids):
        # given bids, return winner(s) and the estimated values (product of 3 terms : lambda, q, bid) of winner(s)
        winners, values = self.get_winners(bids) # allocation mechanism!
        payments_per_click = self.get_payments_per_click(winners, values, bids)
        return winners, payments_per_click

# %%
class UniformBiddingEnvironment:
    def __init__(self, T, n_advertisers, auction, seed=42):
        self.T = T
        self.auction = auction
        self.n_advertisers = n_advertisers
        np.random.seed(seed)
        self.other_bids = np.random.uniform(0, 1, size = (n_advertisers, T))
        self.m_t = self.other_bids.max(axis=0)

    def round(self, round, bid):
        bids_at_round = np.append(self.other_bids[:, round], bid)
        winners, payments_per_click = self.auction.round(bids=bids_at_round)
        return winners, self.m_t[round]
    
    def get_clairvoyant_truthful(self, B, my_valuation):
        ## I compute my sequence of utilities at every round
        utility = (my_valuation-self.m_t)*(my_valuation>=self.m_t)
        #   if valuation less than max_bid of the round, no need to participate
        #   if higher, utility is the difference

        ## Now I have to find the sequence of m_t summing up to budget B and having the maximum sum of utility
        ## In second price auctions, I can find the sequence **greedily**:
        sorted_round_utility = np.flip(np.argsort(utility)) # sorted rounds, from most profitable to less profitable
        clairvoyant_utilities = np.zeros(self.T)
        clairvoyant_bids= np.zeros(self.T)
        clairvoyant_payments = np.zeros(self.T)
        c = 0
        i = 0
        #    (enough budget) and (examined all rounds)
        while c <= B-1 and i < self.T and i < np.count_nonzero(utility):
            clairvoyant_bids[sorted_round_utility[i]] = 1  # simply bid 1 because we are in second-price auction
            clairvoyant_utilities[sorted_round_utility[i]] = utility[sorted_round_utility[i]]
            clairvoyant_payments[sorted_round_utility[i]] = self.m_t[sorted_round_utility[i]]
            c += self.m_t[sorted_round_utility[i]]  # cost is incremented by second price of that round
            i+=1
        return clairvoyant_bids, clairvoyant_utilities, clairvoyant_payments

# %% [markdown]
# ### Bidding Agents

# %% [markdown]
# #### Primal-dual algorithm -> Multiplicative Pacing

# %%
class MultiplicativePacingAgent:
    def __init__(self, valuation, budget, T, eta):
        self.valuation = valuation
        self.budget = budget
        self.eta = eta # learning rate
        self.T = T
        self.rho = self.budget/self.T
        self.lmbd = 1  # shouldn't this be initialized with 0?
        self.t = 0

    def bid(self):
        if self.budget < 1:
            return 0
        return self.valuation/(self.lmbd+1)
    
    def update(self, f_t, c_t):
        self.lmbd = np.clip(self.lmbd-self.eta*(self.rho-c_t), 
                            a_min=0, a_max=1/self.rho)
        self.budget -= c_t

# %% [markdown]
# #### Alternative Multiplicative Pacing -> continuously updated Rho
# Idea behind is that normal MP generally does not deplete budget, so update every round the budget per round

# %%
class ContinuousUpdatedRhoMPAgent:
    def __init__(self, valuation, budget, T, eta):
        self.valuation = valuation
        self.budget = budget
        self.eta = eta # learning rate
        self.T = T
        self.rho = 1.*self.budget/self.T
        self.lmbd = 1
        self.t = 0

    def bid(self):
        if self.budget < 1:
            return 0
        return self.valuation/(self.lmbd+1)
    
    def update(self, f_t, c_t):
        self.lmbd = np.clip(self.lmbd-self.eta*(self.rho-c_t), 
                            a_min=0, a_max=1/self.rho)
        self.budget -= c_t
        self.t += 1
        self.rho = self.budget/(self.T-self.t)

# %% [markdown]
# #### UCB-like algorithm -> simple UCB

# %%
class UCBAgent:
    def __init__(self, valuation, budget, T, K=100, range=1):
        self.T = T
        self.valuation = valuation
        self.budget = budget
        self.K = K
        self.range = range
        self.arms = np.linspace(0, valuation, K)
        self.average_rewards = np.zeros(K)
        self.N_pulls = np.zeros(K)
        self.a_t = None
        self.t = 0

    def bid(self):
        # if budget depleted
        if self.budget < 1:
            return 0
        
        # play every arm at least once
        if self.t < self.K:
            self.a_t = self.t
        else:
            # compute UCB for every arms, choose arm with highest UCB
            ucbs = self.average_rewards + self.range*np.sqrt(2*np.log(self.T)/self.N_pulls)
            self.a_t = np.argmax(ucbs)
        return self.arms[self.a_t]

    def update(self, f_t, c_t):
        self.t += 1
        self.N_pulls[self.a_t] += 1
        self.average_rewards[self.a_t] += (f_t - self.average_rewards[self.a_t])/self.N_pulls[self.a_t]
        self.budget -= c_t

# %% [markdown]
# #### UCB-like algorithm -> UCB with negative feedback when not winning (lost opportunity)
# lost opportunity computed as average utility when winning

# %%
class UCBNFAgent:
    def __init__(self, valuation, budget, T, K=None, range=1):
        self.T = T
        self.valuation = valuation
        self.budget = budget
        if K is None:
            # prescribed by theory
            epsilon = T**(-0.33)
            K = int(1/epsilon)
        self.K = K
        self.range = range
        self.arms = np.linspace(0, valuation, K)
        self.average_rewards = np.zeros(K)
        self.N_pulls = np.zeros(K)
        self.winning_total_reward = 0
        self.won_time = 0
        self.a_t = None
        self.t = 0

    def bid(self):
        # if budget depleted
        if self.budget < 1:
            return 0
        
        # play every arm at least once
        if self.t < self.K:
            self.a_t = self.t
        else:
            # compute UCB for every arms, choose arm with highest UCB
            ucbs = self.average_rewards + self.range*np.sqrt(2*np.log(self.T)/self.N_pulls)
            self.a_t = np.argmax(ucbs)
            # if(self.t<50):
            #     print(f'round {self.t} : {ucbs}\n bidded {self.arms[self.a_t]} with ucb={ucbs[self.a_t]}')
        return self.arms[self.a_t]

    def update(self, f_t, c_t):
        self.N_pulls[self.a_t] += 1
        
        if(f_t>0):
            self.won_time += 1
            self.winning_total_reward += f_t
        elif(self.t >= self.K):
            f_t = - (self.winning_total_reward / self.won_time)
    
        self.average_rewards[self.a_t] += (f_t - self.average_rewards[self.a_t])/self.N_pulls[self.a_t]
        self.budget -= c_t
        self.t += 1

# %% [markdown]
# ### Simulation

# %%
def MinMaxScaler(original, min_x, max_x):
    return (original - min_x) / (max_x - min_x)

def MinMaxRescaler(scaled, min_x, max_x):
    return min_x + (max_x - min_x) * scaled

np.random.seed(2)

# product 
min_price, max_price = 10, 20
production_cost = 10
price_discretization = 20
payed_bid_per_user = 0
scaled_payed_bid_per_user = 0
scaled_min_price = MinMaxScaler(min_price, min_price, max_price)
scaled_max_price = MinMaxScaler(max_price, min_price, max_price)
scaled_cost = MinMaxScaler(production_cost, min_price, max_price)  # equals to scaled_min_price

# Pricing Environment and Agent
# Logistic model example
model='logistic'
alpha=0.8
beta=-3
scale=2
TotalDays = 365
pricing_env = StochasticPricingEnvironment(model, alpha, beta)
pricing_agent = GPUCBAgent(TotalDays, scaled_min_price, scaled_max_price, discretization=price_discretization, scale=scale)
n_customers_t = 0        # to be determined every day after bidding
# for clairvoyant's use
prices = np.linspace(scaled_min_price, scaled_max_price, price_discretization)
conversion_probabilities = StochasticPricingEnvironment.generate_probability(model, alpha, beta, prices)


# Bidding Environment parameters
n_users = 10000
n_competitors = 2
ctrs = np.ones(n_competitors+1)
B = 100
auction = SecondPriceAuction(ctrs)
bidding_agent_profits = []
clairvoyant_profits = []

# Foreach day
for day in range(TotalDays):
    # pricing agent sets the price of the day
    p_t, purchase_probability_t, average_bid_cost_t = pricing_agent.pull_arm()

    # Bidding Environment
    bidding_env = UniformBiddingEnvironment(n_users, n_competitors, auction, seed=day)

    # Bidding Agents
    my_valuation_t = p_t*purchase_probability_t # equals to daily_set_price (which took into account the production cost)

    # Exploratory round to estimate the purchase probability of each price
    if(day == 0):
        my_valuation_t = scaled_max_price
    
    
    eta = 1/np.sqrt(n_users) # from theory
    agentMP = MultiplicativePacingAgent(valuation=my_valuation_t,
                                    budget=B,
                                    T=n_users, 
                                    eta=eta)
    # agentCURMP = ContinuousUpdatedRhoMPAgent(valuation=my_valuation_t,
    #                                 budget=B,
    #                                 T=n_users, 
    #                                 eta=eta)
    # agentUCB = UCBAgent(my_valuation_t, B, n_users, range=my_valuation_t/2)
    # agentNF = UCBNFAgent(my_valuation_t, B, n_users, range=my_valuation_t/2)
    # agentNF1 = UCBNFAgent(my_valuation_t, B, n_users, range=0.1)    # range works as the hyperparameter in this problem
    
    bidding_agents = {
        "Multiplicative Pacing": agentMP,
        # "Continuously updated Rho MP": agentCURMP,
        # "Plain UCB": agentUCB,
        # "UCB with negative feedback": agentNF,
        # "UCBNF with range 0.1" : agentNF1
    }

    utilities = np.zeros((len(bidding_agents), n_users))
    my_bids = np.zeros((len(bidding_agents), n_users))
    my_payments = np.zeros((len(bidding_agents), n_users))
    total_wins = np.zeros((len(bidding_agents)))
    bidding_agent_profit=0
    number_sale_t=0

    np.random.seed(day)
    for u in range(n_users):
        # bidding process
        for idx, (name, agent) in enumerate(bidding_agents.items()):
            my_bid = agent.bid()
            winners, m_t = bidding_env.round(u, my_bid)
            my_win = int(winners==n_competitors)
            f_t, c_t = (my_valuation_t-m_t)*my_win, m_t*my_win
            agent.update(f_t, c_t)
            utilities[idx,u] = f_t
            my_bids[idx,u] = my_bid
            my_payments[idx,u] = c_t
            total_wins[idx] += my_win
    if(total_wins[0] != 0):
        n_customers_t = total_wins[0]
        scaled_payed_bid_per_user = np.sum(my_payments[0,:]) / total_wins[0]
    
    
    # Update pricing agent
    # Exploratory round to estimate purchase probability
    if(day == 0):
        original_a_t = pricing_agent.a_t
        customers_per_price = int(n_customers_t / price_discretization)
        for idx, price in enumerate(pricing_agent.arms):
            sales_per_price = pricing_env.round(price, customers_per_price)
            pricing_agent.a_t = idx
            pricing_agent.update(sales_per_price, customers_per_price)
            # print(f'Price # {idx} : {price} with {sales_per_price}/{customers_per_price} sales')
        pricing_agent.a_t = original_a_t
    # Normal rounds
    else:
        number_sale_t = pricing_env.round(p_t, n_customers_t)
        pricing_agent.update(number_sale_t, n_customers_t, scaled_payed_bid_per_user, n_customers_t/n_users)
        bidding_agent_profit = number_sale_t*p_t-np.sum(my_payments[0,:])
        bidding_agent_profits.append(bidding_agent_profit)

    # Clairvoyant utilities
    clairvoyant_bids, clairvoyant_utilities, clairvoyant_payments = bidding_env.get_clairvoyant_truthful(B, p_t*conversion_probabilities[pricing_agent.a_t])
    clairvoyant_customers = np.count_nonzero(clairvoyant_bids)
    clairvoyant_sales =  int(clairvoyant_customers * conversion_probabilities[pricing_agent.a_t])
    clairvoyant_profit = clairvoyant_sales*p_t - np.sum(clairvoyant_payments)
    if(clairvoyant_profit <=0 and day>0):
        print("Total revenue :")
        print(number_sale_t*p_t)
        print(clairvoyant_sales*p_t)

        print("Total payment :")
        print(np.sum(my_payments[0,:]))
        print(np.sum(clairvoyant_payments))

        print("Total won auction :")
        print(np.count_nonzero(my_payments[0,:]))
        print(np.count_nonzero(clairvoyant_payments))

        print("Mean payed bid :")
        print(np.sum(my_payments[0,:])/np.count_nonzero(my_payments[0,:]))
        print(np.sum(clairvoyant_payments)/np.count_nonzero(clairvoyant_payments))
        break
    clairvoyant_profits.append(clairvoyant_profit)

    # logging
    if(n_customers_t == 0):
        n_customers_t=1
    if(clairvoyant_customers == 0):
        clairvoyant_customers=1
    print(f'At day {day} :\tprice_t = {p_t:.4f}, with estimated purchase probability = {purchase_probability_t:.4f}\
          \n\t\tmy valuation = {my_valuation_t:.4f}, won {int(n_customers_t)}/{n_users} auctions, with a mean bid of {scaled_payed_bid_per_user:.4f} \
          \n\t\twe sold {number_sale_t}/{int(n_customers_t)} ({number_sale_t/n_customers_t*100:.2f}%) products, for a total net profit of {bidding_agent_profit:.4f}\
          \n\t\tclairvoyant sale : {clairvoyant_sales}/{clairvoyant_customers} ({clairvoyant_sales/clairvoyant_customers*100:.2f}%), for a total net profit of {clairvoyant_profit:.4f}\n')
    n_customers_t=0
    clairvoyant_customers=0
# Out:
# At day 0 :	price_t = 0.0000, with estimated purchase probability = 1.0000
# 		my valuation = 1.0000, won 349/10000 auctions, with a mean bid of 0.2842
# 		we sold 0/349 (0.00%) products, for a total net profit of 0.0000
# 		clairvoyant sale : 0/1 (0.00%), for a total net profit of 0.0000
#
# At day 1 :	price_t = 0.4737, with estimated purchase probability = 0.4088
# 		my valuation = 0.1936, won 172/10000 auctions, with a mean bid of 0.0919
# 		we sold 62/172 (36.05%) products, for a total net profit of 13.5696
# 		clairvoyant sale : 95/273 (34.80%), for a total net profit of 14.7007
#
# At day 2 :	price_t = 0.4211, with estimated purchase probability = 0.4503
# 		my valuation = 0.1896, won 177/10000 auctions, with a mean bid of 0.0868
# 		we sold 78/177 (44.07%) products, for a total net profit of 17.4766
# 		clairvoyant sale : 106/276 (38.41%), for a total net profit of 15.0051
#
# At day 3 :	price_t = 0.5263, with estimated purchase probability = 0.3516
# 		my valuation = 0.1850, won 150/10000 auctions, with a mean bid of 0.0896
# 		we sold 48/150 (32.00%) products, for a total net profit of 11.8171
# 		clairvoyant sale : 87/277 (31.41%), for a total net profit of 14.2614
#
# At day 4 :	price_t = 1.0000, with estimated purchase probability = 0.1838
# 		my valuation = 0.1838, won 172/10000 auctions, with a mean bid of 0.0871
# 		we sold 25/172 (14.53%) products, for a total net profit of 10.0216
# 		clairvoyant sale : 11/118 (9.32%), for a total net profit of 2.7514
#
# At day 5 :	price_t = 0.3684, with estimated purchase probability = 0.4903
# 		my valuation = 0.1806, won 140/10000 auctions, with a mean bid of 0.0876
# 		we sold 55/140 (39.29%) products, for a total net profit of 8.0008
# 		clairvoyant sale : 102/242 (42.15%), for a total net profit of 11.4657
#
# At day 6 :	price_t = 0.5789, with estimated purchase probability = 0.2950
# 		my valuation = 0.1708, won 132/10000 auctions, with a mean bid of 0.0803
# 		we sold 45/132 (34.09%) products, for a total net profit of 15.4477
# 		clairvoyant sale : 72/257 (28.02%), for a total net profit of 14.0129
#
# At day 7 :	price_t = 0.3158, with estimated purchase probability = 0.5185
# 		my valuation = 0.1637, won 113/10000 auctions, with a mean bid of 0.0806
# 		we sold 46/113 (40.71%) products, for a total net profit of 5.4197
# 		clairvoyant sale : 100/216 (46.30%), for a total net profit of 9.6344
#
# At day 8 :	price_t = 0.6316, with estimated purchase probability = 0.2551
# 		my valuation = 0.1611, won 137/10000 auctions, with a mean bid of 0.0790
# 		we sold 38/137 (27.74%) products, for a total net profit of 13.1740
# 		clairvoyant sale : 65/261 (24.90%), for a total net profit of 13.7372
#
# At day 9 :	price_t = 0.6842, with estimated purchase probability = 0.2177
# 		my valuation = 0.1490, won 104/10000 auctions, with a mean bid of 0.0703
# 		we sold 14/104 (13.46%) products, for a total net profit of 2.2680
# 		clairvoyant sale : 55/251 (21.91%), for a total net profit of 11.5451
#
# At day 10 :	price_t = 0.2632, with estimated purchase probability = 0.5393
# 		my valuation = 0.1419, won 105/10000 auctions, with a mean bid of 0.0697
# 		we sold 48/105 (45.71%) products, for a total net profit of 5.3116
# 		clairvoyant sale : 100/199 (50.25%), for a total net profit of 8.3880
#
# At day 11 :	price_t = 0.9474, with estimated purchase probability = 0.1410
# 		my valuation = 0.1336, won 101/10000 auctions, with a mean bid of 0.0625
# 		we sold 9/101 (8.91%) products, for a total net profit of 2.2096
# 		clairvoyant sale : 15/132 (11.36%), for a total net profit of 4.9287
#
# At day 12 :	price_t = 0.7368, with estimated purchase probability = 0.1745
# 		my valuation = 0.1286, won 62/10000 auctions, with a mean bid of 0.0679
# 		we sold 9/62 (14.52%) products, for a total net profit of 2.4224
# 		clairvoyant sale : 36/187 (19.25%), for a total net profit of 8.0641
#
# At day 13 :	price_t = 0.2105, with estimated purchase probability = 0.5575
# 		my valuation = 0.1174, won 82/10000 auctions, with a mean bid of 0.0557
# 		we sold 39/82 (47.56%) products, for a total net profit of 3.6432
# 		clairvoyant sale : 81/150 (54.00%), for a total net profit of 5.9524
#
# At day 14 :	price_t = 0.7895, with estimated purchase probability = 0.1448
# 		my valuation = 0.1143, won 47/10000 auctions, with a mean bid of 0.0581
# 		we sold 8/47 (17.02%) products, for a total net profit of 3.5856
# 		clairvoyant sale : 27/157 (17.20%), for a total net profit of 6.3470
#
# At day 15 :	price_t = 0.8947, with estimated purchase probability = 0.1245
# 		my valuation = 0.1114, won 65/10000 auctions, with a mean bid of 0.0545
# 		we sold 11/65 (16.92%) products, for a total net profit of 6.3021
# 		clairvoyant sale : 18/140 (12.86%), for a total net profit of 5.1230
#
# At day 16 :	price_t = 0.8421, with estimated purchase probability = 0.1343
# 		my valuation = 0.1131, won 69/10000 auctions, with a mean bid of 0.0499
# 		we sold 8/69 (11.59%) products, for a total net profit of 3.2961
# 		clairvoyant sale : 24/163 (14.72%), for a total net profit of 7.3273
#
# At day 17 :	price_t = 0.1579, with estimated purchase probability = 0.5735
# 		my valuation = 0.0906, won 39/10000 auctions, with a mean bid of 0.0514
# 		we sold 24/39 (61.54%) products, for a total net profit of 1.7838
# 		clairvoyant sale : 47/81 (58.02%), for a total net profit of 2.2319
#
# At day 18 :	price_t = 0.4737, with estimated purchase probability = 0.3830
# 		my valuation = 0.1814, won 148/10000 auctions, with a mean bid of 0.0854
# 		we sold 41/148 (27.70%) products, for a total net profit of 6.7861
# 		clairvoyant sale : 102/292 (34.93%), for a total net profit of 15.4648
#
# At day 19 :	price_t = 0.4211, with estimated purchase probability = 0.4166
# 		my valuation = 0.1754, won 149/10000 auctions, with a mean bid of 0.0798
# 		we sold 51/149 (34.23%) products, for a total net profit of 9.5771
# 		clairvoyant sale : 105/273 (38.46%), for a total net profit of 15.1498
#
# At day 20 :	price_t = 0.5263, with estimated purchase probability = 0.3279
# 		my valuation = 0.1726, won 122/10000 auctions, with a mean bid of 0.0795
# 		we sold 33/122 (27.05%) products, for a total net profit of 7.6702
# 		clairvoyant sale : 80/255 (31.37%), for a total net profit of 14.2777
#
# At day 21 :	price_t = 0.1053, with estimated purchase probability = 0.6059
# 		my valuation = 0.0638, won 20/10000 auctions, with a mean bid of 0.0353
# 		we sold 16/20 (80.00%) products, for a total net profit of 0.9786
# 		clairvoyant sale : 25/42 (59.52%), for a total net profit of 0.7880
#
# At day 22 :	price_t = 0.3684, with estimated purchase probability = 0.4496
# 		my valuation = 0.1656, won 115/10000 auctions, with a mean bid of 0.0764
# 		we sold 49/115 (42.61%) products, for a total net profit of 9.2655
# 		clairvoyant sale : 101/240 (42.08%), for a total net profit of 11.8693
#
# At day 23 :	price_t = 0.5789, with estimated purchase probability = 0.2786
# 		my valuation = 0.1613, won 124/10000 auctions, with a mean bid of 0.0764
# 		we sold 41/124 (33.06%) products, for a total net profit of 14.2600
# 		clairvoyant sale : 75/267 (28.09%), for a total net profit of 14.4936
#
# At day 24 :	price_t = 1.0000, with estimated purchase probability = 0.1584
# 		my valuation = 0.1584, won 134/10000 auctions, with a mean bid of 0.0753
# 		we sold 20/134 (14.93%) products, for a total net profit of 9.9126
# 		clairvoyant sale : 10/110 (9.09%), for a total net profit of 2.8514
#
# At day 25 :	price_t = 0.3158, with estimated purchase probability = 0.4888
# 		my valuation = 0.1543, won 100/10000 auctions, with a mean bid of 0.0703
# 		we sold 36/100 (36.00%) products, for a total net profit of 4.3366
# 		clairvoyant sale : 97/211 (45.97%), for a total net profit of 9.8186
#
# At day 26 :	price_t = 0.6316, with estimated purchase probability = 0.2427
# 		my valuation = 0.1533, won 122/10000 auctions, with a mean bid of 0.0700
# 		we sold 32/122 (26.23%) products, for a total net profit of 11.6749
# 		clairvoyant sale : 66/264 (25.00%), for a total net profit of 14.4156
#
# At day 27 :	price_t = 0.6842, with estimated purchase probability = 0.2091
# 		my valuation = 0.1431, won 75/10000 auctions, with a mean bid of 0.0664
# 		we sold 16/75 (21.33%) products, for a total net profit of 5.9684
# 		clairvoyant sale : 45/203 (22.17%), for a total net profit of 10.0150
#
# At day 28 :	price_t = 0.2632, with estimated purchase probability = 0.5173
# 		my valuation = 0.1361, won 93/10000 auctions, with a mean bid of 0.0698
# 		we sold 48/93 (51.61%) products, for a total net profit of 6.1367
# 		clairvoyant sale : 86/172 (50.00%), for a total net profit of 7.4135
#
# At day 29 :	price_t = 0.9474, with estimated purchase probability = 0.1375
# 		my valuation = 0.1303, won 80/10000 auctions, with a mean bid of 0.0648
# 		we sold 12/80 (15.00%) products, for a total net profit of 6.1821
# 		clairvoyant sale : 12/113 (10.62%), for a total net profit of 3.0691
#
# At day 30 :	price_t = 0.7368, with estimated purchase probability = 0.1797
# 		my valuation = 0.1324, won 82/10000 auctions, with a mean bid of 0.0630
# 		we sold 17/82 (20.73%) products, for a total net profit of 7.3580
# 		clairvoyant sale : 40/207 (19.32%), for a total net profit of 9.7491
#
# At day 31 :	price_t = 0.7895, with estimated purchase probability = 0.1583
# 		my valuation = 0.1250, won 85/10000 auctions, with a mean bid of 0.0642
# 		we sold 13/85 (15.29%) products, for a total net profit of 4.8066
# 		clairvoyant sale : 35/207 (16.91%), for a total net profit of 8.5331
#
# At day 32 :	price_t = 0.8421, with estimated purchase probability = 0.1422
# 		my valuation = 0.1198, won 61/10000 auctions, with a mean bid of 0.0617
# 		we sold 12/61 (19.67%) products, for a total net profit of 6.3386
# 		clairvoyant sale : 20/139 (14.39%), for a total net profit of 4.9852
#
# At day 33 :	price_t = 0.8947, with estimated purchase probability = 0.1390
# 		my valuation = 0.1244, won 71/10000 auctions, with a mean bid of 0.0621
# 		we sold 7/71 (9.86%) products, for a total net profit of 1.8556
# 		clairvoyant sale : 17/134 (12.69%), for a total net profit of 4.6463
#
# At day 34 :	price_t = 0.2105, with estimated purchase probability = 0.5539
# 		my valuation = 0.1166, won 55/10000 auctions, with a mean bid of 0.0602
# 		we sold 36/55 (65.45%) products, for a total net profit of 4.2657
# 		clairvoyant sale : 65/121 (53.72%), for a total net profit of 4.0853
#
# At day 35 :	price_t = 0.4211, with estimated purchase probability = 0.4041
# 		my valuation = 0.1702, won 131/10000 auctions, with a mean bid of 0.0809
# 		we sold 41/131 (31.30%) products, for a total net profit of 6.6659
# 		clairvoyant sale : 99/257 (38.52%), for a total net profit of 13.9317
#
# At day 36 :	price_t = 0.4737, with estimated purchase probability = 0.3587
# 		my valuation = 0.1699, won 125/10000 auctions, with a mean bid of 0.0790
# 		we sold 51/125 (40.80%) products, for a total net profit of 14.2867
# 		clairvoyant sale : 90/259 (34.75%), for a total net profit of 14.2287
#
# At day 37 :	price_t = 0.5263, with estimated purchase probability = 0.3210
# 		my valuation = 0.1689, won 141/10000 auctions, with a mean bid of 0.0774
# 		we sold 56/141 (39.72%) products, for a total net profit of 18.5551
# 		clairvoyant sale : 95/304 (31.25%), for a total net profit of 16.5342
#
# At day 38 :	price_t = 0.5789, with estimated purchase probability = 0.2854
# 		my valuation = 0.1652, won 125/10000 auctions, with a mean bid of 0.0811
# 		we sold 36/125 (28.80%) products, for a total net profit of 10.7106
# 		clairvoyant sale : 73/261 (27.97%), for a total net profit of 13.6746
#
# At day 39 :	price_t = 0.3684, with estimated purchase probability = 0.4444
# 		my valuation = 0.1637, won 128/10000 auctions, with a mean bid of 0.0742
# 		we sold 62/128 (48.44%) products, for a total net profit of 13.3407
# 		clairvoyant sale : 100/238 (42.02%), for a total net profit of 12.7699
#
# At day 40 :	price_t = 0.6316, with estimated purchase probability = 0.2484
# 		my valuation = 0.1569, won 123/10000 auctions, with a mean bid of 0.0741
# 		we sold 25/123 (20.33%) products, for a total net profit of 6.6773
# 		clairvoyant sale : 62/248 (25.00%), for a total net profit of 13.7871
#
# At day 41 :	price_t = 0.0526, with estimated purchase probability = 0.6694
# 		my valuation = 0.0352, won 3/10000 auctions, with a mean bid of 0.0184
# 		we sold 3/3 (100.00%) products, for a total net profit of 0.1026
# 		clairvoyant sale : 8/13 (61.54%), for a total net profit of 0.0926
#
# At day 42 :	price_t = 0.1579, with estimated purchase probability = 0.6224
# 		my valuation = 0.0983, won 48/10000 auctions, with a mean bid of 0.0474
# 		we sold 29/48 (60.42%) products, for a total net profit of 2.3026
# 		clairvoyant sale : 49/85 (57.65%), for a total net profit of 2.5688
#
# At day 43 :	price_t = 0.3158, with estimated purchase probability = 0.4833
# 		my valuation = 0.1526, won 103/10000 auctions, with a mean bid of 0.0720
# 		we sold 45/103 (43.69%) products, for a total net profit of 6.7953
# 		clairvoyant sale : 91/198 (45.96%), for a total net profit of 9.6185
#
# At day 44 :	price_t = 0.6842, with estimated purchase probability = 0.2146
# 		my valuation = 0.1468, won 98/10000 auctions, with a mean bid of 0.0753
# 		we sold 26/98 (26.53%) products, for a total net profit of 10.4133
# 		clairvoyant sale : 49/221 (22.17%), for a total net profit of 10.4518
#
# At day 45 :	price_t = 1.0000, with estimated purchase probability = 0.1518
# 		my valuation = 0.1518, won 104/10000 auctions, with a mean bid of 0.0766
# 		we sold 18/104 (17.31%) products, for a total net profit of 10.0322
# 		clairvoyant sale : 9/93 (9.68%), for a total net profit of 2.5421
#
# At day 46 :	price_t = 0.7368, with estimated purchase probability = 0.1872
# 		my valuation = 0.1380, won 81/10000 auctions, with a mean bid of 0.0698
# 		we sold 19/81 (23.46%) products, for a total net profit of 8.3480
# 		clairvoyant sale : 39/202 (19.31%), for a total net profit of 8.4640
#
# At day 47 :	price_t = 0.2632, with estimated purchase probability = 0.5238
# 		my valuation = 0.1379, won 80/10000 auctions, with a mean bid of 0.0636
# 		we sold 45/80 (56.25%) products, for a total net profit of 6.7572
# 		clairvoyant sale : 77/155 (49.68%), for a total net profit of 6.7311
#
# At day 48 :	price_t = 0.9474, with estimated purchase probability = 0.1413
# 		my valuation = 0.1339, won 92/10000 auctions, with a mean bid of 0.0672
# 		we sold 5/92 (5.43%) products, for a total net profit of -1.4485
# 		clairvoyant sale : 14/125 (11.20%), for a total net profit of 3.9291
#
# At day 49 :	price_t = 0.7895, with estimated purchase probability = 0.1637
# 		my valuation = 0.1292, won 93/10000 auctions, with a mean bid of 0.0626
# 		we sold 14/93 (15.05%) products, for a total net profit of 5.2349
# 		clairvoyant sale : 34/202 (16.83%), for a total net profit of 8.8964
#
# At day 50 :	price_t = 0.8421, with estimated purchase probability = 0.1448
# 		my valuation = 0.1220, won 70/10000 auctions, with a mean bid of 0.0565
# 		we sold 10/70 (14.29%) products, for a total net profit of 4.4677
# 		clairvoyant sale : 22/147 (14.97%), for a total net profit of 6.5190
#
# At day 51 :	price_t = 0.5263, with estimated purchase probability = 0.3243
# 		my valuation = 0.1707, won 135/10000 auctions, with a mean bid of 0.0808
# 		we sold 44/135 (32.59%) products, for a total net profit of 12.2511
# 		clairvoyant sale : 89/283 (31.45%), for a total net profit of 15.3957
#
# At day 52 :	price_t = 0.4737, with estimated purchase probability = 0.3623
# 		my valuation = 0.1716, won 147/10000 auctions, with a mean bid of 0.0767
# 		we sold 59/147 (40.14%) products, for a total net profit of 16.6744
# 		clairvoyant sale : 94/270 (34.81%), for a total net profit of 16.5720
#
# At day 53 :	price_t = 0.4211, with estimated purchase probability = 0.4025
# 		my valuation = 0.1695, won 136/10000 auctions, with a mean bid of 0.0783
# 		we sold 61/136 (44.85%) products, for a total net profit of 15.0364
# 		clairvoyant sale : 99/258 (38.37%), for a total net profit of 14.7805
#
# At day 54 :	price_t = 0.5789, with estimated purchase probability = 0.2895
# 		my valuation = 0.1676, won 120/10000 auctions, with a mean bid of 0.0771
# 		we sold 28/120 (23.33%) products, for a total net profit of 6.9584
# 		clairvoyant sale : 74/264 (28.03%), for a total net profit of 13.6277
#
# At day 55 :	price_t = 0.2105, with estimated purchase probability = 0.5732
# 		my valuation = 0.1207, won 75/10000 auctions, with a mean bid of 0.0536
# 		we sold 46/75 (61.33%) products, for a total net profit of 5.6675
# 		clairvoyant sale : 72/134 (53.73%), for a total net profit of 5.5329
#
# At day 56 :	price_t = 0.8947, with estimated purchase probability = 0.1343
# 		my valuation = 0.1202, won 79/10000 auctions, with a mean bid of 0.0614
# 		we sold 17/79 (21.52%) products, for a total net profit of 10.3623
# 		clairvoyant sale : 20/159 (12.58%), for a total net profit of 4.9924
#
# At day 57 :	price_t = 0.3684, with estimated purchase probability = 0.4438
# 		my valuation = 0.1635, won 126/10000 auctions, with a mean bid of 0.0767
# 		we sold 53/126 (42.06%) products, for a total net profit of 9.8627
# 		clairvoyant sale : 109/259 (42.08%), for a total net profit of 12.9393
#
# At day 58 :	price_t = 0.1053, with estimated purchase probability = 0.6746
# 		my valuation = 0.0710, won 27/10000 auctions, with a mean bid of 0.0374
# 		we sold 18/27 (66.67%) products, for a total net profit of 0.8854
# 		clairvoyant sale : 27/45 (60.00%), for a total net profit of 0.8390
#
# At day 59 :	price_t = 0.6316, with estimated purchase probability = 0.2509
# 		my valuation = 0.1585, won 114/10000 auctions, with a mean bid of 0.0793
# 		we sold 35/114 (30.70%) products, for a total net profit of 13.0685
# 		clairvoyant sale : 63/252 (25.00%), for a total net profit of 12.6683
#
# At day 60 :	price_t = 0.3158, with estimated purchase probability = 0.4848
# 		my valuation = 0.1531, won 106/10000 auctions, with a mean bid of 0.0727
# 		we sold 53/106 (50.00%) products, for a total net profit of 9.0293
# 		clairvoyant sale : 99/215 (46.05%), for a total net profit of 10.0146
#
# At day 61 :	price_t = 0.6842, with estimated purchase probability = 0.2197
# 		my valuation = 0.1503, won 112/10000 auctions, with a mean bid of 0.0747
# 		we sold 29/112 (25.89%) products, for a total net profit of 11.4703
# 		clairvoyant sale : 59/266 (22.18%), for a total net profit of 12.9754
#
# At day 62 :	price_t = 1.0000, with estimated purchase probability = 0.1496
# 		my valuation = 0.1496, won 108/10000 auctions, with a mean bid of 0.0696
# 		we sold 5/108 (4.63%) products, for a total net profit of -2.5140
# 		clairvoyant sale : 10/101 (9.90%), for a total net profit of 3.5829
#
# At day 63 :	price_t = 0.7368, with estimated purchase probability = 0.1932
# 		my valuation = 0.1423, won 100/10000 auctions, with a mean bid of 0.0722
# 		we sold 20/100 (20.00%) products, for a total net profit of 7.5130
# 		clairvoyant sale : 40/209 (19.14%), for a total net profit of 9.1114
#
# At day 64 :	price_t = 0.2632, with estimated purchase probability = 0.5286
# 		my valuation = 0.1391, won 109/10000 auctions, with a mean bid of 0.0678
# 		we sold 53/109 (48.62%) products, for a total net profit of 6.5619
# 		clairvoyant sale : 94/188 (50.00%), for a total net profit of 8.4005
#
# At day 65 :	price_t = 0.5263, with estimated purchase probability = 0.3269
# 		my valuation = 0.1720, won 136/10000 auctions, with a mean bid of 0.0834
# 		we sold 47/136 (34.56%) products, for a total net profit of 13.4000
# 		clairvoyant sale : 85/272 (31.25%), for a total net profit of 14.4218
#
# At day 66 :	price_t = 0.4737, with estimated purchase probability = 0.3646
# 		my valuation = 0.1727, won 118/10000 auctions, with a mean bid of 0.0830
# 		we sold 43/118 (36.44%) products, for a total net profit of 10.5745
# 		clairvoyant sale : 95/273 (34.80%), for a total net profit of 13.7915
#
# At day 67 :	price_t = 0.7895, with estimated purchase probability = 0.1685
# 		my valuation = 0.1331, won 85/10000 auctions, with a mean bid of 0.0654
# 		we sold 15/85 (17.65%) products, for a total net profit of 6.2832
# 		clairvoyant sale : 30/177 (16.95%), for a total net profit of 7.7757
#
# At day 68 :	price_t = 0.5789, with estimated purchase probability = 0.2914
# 		my valuation = 0.1687, won 126/10000 auctions, with a mean bid of 0.0788
# 		we sold 40/126 (31.75%) products, for a total net profit of 13.2288
# 		clairvoyant sale : 79/282 (28.01%), for a total net profit of 14.6111
#
# At day 69 :	price_t = 0.4211, with estimated purchase probability = 0.4031
# 		my valuation = 0.1697, won 144/10000 auctions, with a mean bid of 0.0813
# 		we sold 54/144 (37.50%) products, for a total net profit of 11.0286
# 		clairvoyant sale : 107/279 (38.35%), for a total net profit of 14.7032
#
# At day 70 :	price_t = 0.1579, with estimated purchase probability = 0.6215
# 		my valuation = 0.0981, won 54/10000 auctions, with a mean bid of 0.0480
# 		we sold 26/54 (48.15%) products, for a total net profit of 1.5118
# 		clairvoyant sale : 52/91 (57.14%), for a total net profit of 2.6961
#
# At day 71 :	price_t = 0.6316, with estimated purchase probability = 0.2580
# 		my valuation = 0.1629, won 141/10000 auctions, with a mean bid of 0.0725
# 		we sold 36/141 (25.53%) products, for a total net profit of 12.5142
# 		clairvoyant sale : 69/279 (24.73%), for a total net profit of 15.0730
#
# At day 72 :	price_t = 0.8421, with estimated purchase probability = 0.1486
# 		my valuation = 0.1251, won 62/10000 auctions, with a mean bid of 0.0620
# 		we sold 6/62 (9.68%) products, for a total net profit of 1.2094
# 		clairvoyant sale : 19/131 (14.50%), for a total net profit of 4.9901
#
# At day 73 :	price_t = 0.3684, with estimated purchase probability = 0.4401
# 		my valuation = 0.1621, won 131/10000 auctions, with a mean bid of 0.0737
# 		we sold 49/131 (37.40%) products, for a total net profit of 8.3952
# 		clairvoyant sale : 104/247 (42.11%), for a total net profit of 13.7004
#
# At day 74 :	price_t = 0.6842, with estimated purchase probability = 0.2238
# 		my valuation = 0.1531, won 107/10000 auctions, with a mean bid of 0.0721
# 		we sold 20/107 (18.69%) products, for a total net profit of 5.9688
# 		clairvoyant sale : 48/219 (21.92%), for a total net profit of 10.8673
#
# At day 75 :	price_t = 0.2105, with estimated purchase probability = 0.5646
# 		my valuation = 0.1189, won 75/10000 auctions, with a mean bid of 0.0615
# 		we sold 42/75 (56.00%) products, for a total net profit of 4.2301
# 		clairvoyant sale : 76/142 (53.52%), for a total net profit of 4.8631
#
# At day 76 :	price_t = 0.3158, with estimated purchase probability = 0.4775
# 		my valuation = 0.1508, won 102/10000 auctions, with a mean bid of 0.0703
# 		we sold 46/102 (45.10%) products, for a total net profit of 7.3606
# 		clairvoyant sale : 92/199 (46.23%), for a total net profit of 10.0498
#
# At day 77 :	price_t = 0.8947, with estimated purchase probability = 0.1330
# 		my valuation = 0.1190, won 69/10000 auctions, with a mean bid of 0.0539
# 		we sold 13/69 (18.84%) products, for a total net profit of 7.9138
# 		clairvoyant sale : 17/131 (12.98%), for a total net profit of 5.4334
#
# At day 78 :	price_t = 0.9474, with estimated purchase probability = 0.1312
# 		my valuation = 0.1243, won 86/10000 auctions, with a mean bid of 0.0560
# 		we sold 5/86 (5.81%) products, for a total net profit of -0.0760
# 		clairvoyant sale : 13/118 (11.02%), for a total net profit of 4.5580
#
# At day 79 :	price_t = 0.5263, with estimated purchase probability = 0.3268
# 		my valuation = 0.1720, won 127/10000 auctions, with a mean bid of 0.0761
# 		we sold 35/127 (27.56%) products, for a total net profit of 8.7584
# 		clairvoyant sale : 82/261 (31.42%), for a total net profit of 14.7141
#
# At day 80 :	price_t = 0.4737, with estimated purchase probability = 0.3613
# 		my valuation = 0.1712, won 134/10000 auctions, with a mean bid of 0.0795
# 		we sold 46/134 (34.33%) products, for a total net profit of 11.1353
# 		clairvoyant sale : 94/270 (34.81%), for a total net profit of 15.3089
#
# At day 81 :	price_t = 0.5789, with estimated purchase probability = 0.2895
# 		my valuation = 0.1676, won 145/10000 auctions, with a mean bid of 0.0819
# 		we sold 45/145 (31.03%) products, for a total net profit of 14.1826
# 		clairvoyant sale : 77/275 (28.00%), for a total net profit of 14.9344
#
# At day 82 :	price_t = 0.7368, with estimated purchase probability = 0.1930
# 		my valuation = 0.1422, won 92/10000 auctions, with a mean bid of 0.0634
# 		we sold 16/92 (17.39%) products, for a total net profit of 5.9545
# 		clairvoyant sale : 35/182 (19.23%), for a total net profit of 9.2272
#
# At day 83 :	price_t = 0.4211, with estimated purchase probability = 0.3980
# 		my valuation = 0.1676, won 130/10000 auctions, with a mean bid of 0.0831
# 		we sold 49/130 (37.69%) products, for a total net profit of 9.8270
# 		clairvoyant sale : 99/258 (38.37%), for a total net profit of 13.6712
#
# At day 84 :	price_t = 0.6316, with estimated purchase probability = 0.2550
# 		my valuation = 0.1611, won 120/10000 auctions, with a mean bid of 0.0821
# 		we sold 28/120 (23.33%) products, for a total net profit of 7.8382
# 		clairvoyant sale : 65/262 (24.81%), for a total net profit of 12.2355
#
# At day 85 :	price_t = 0.2632, with estimated purchase probability = 0.5180
# 		my valuation = 0.1363, won 87/10000 auctions, with a mean bid of 0.0660
# 		we sold 44/87 (50.57%) products, for a total net profit of 5.8408
# 		clairvoyant sale : 88/177 (49.72%), for a total net profit of 7.3365
#
# At day 86 :	price_t = 0.3684, with estimated purchase probability = 0.4351
# 		my valuation = 0.1603, won 119/10000 auctions, with a mean bid of 0.0769
# 		we sold 52/119 (43.70%) products, for a total net profit of 10.0034
# 		clairvoyant sale : 94/222 (42.34%), for a total net profit of 11.7145
#
# At day 87 :	price_t = 0.7895, with estimated purchase probability = 0.1662
# 		my valuation = 0.1312, won 94/10000 auctions, with a mean bid of 0.0636
# 		we sold 18/94 (19.15%) products, for a total net profit of 8.2356
# 		clairvoyant sale : 34/202 (16.83%), for a total net profit of 9.0057
#
# At day 88 :	price_t = 0.6842, with estimated purchase probability = 0.2225
# 		my valuation = 0.1522, won 96/10000 auctions, with a mean bid of 0.0759
# 		we sold 23/96 (23.96%) products, for a total net profit of 8.4472
# 		clairvoyant sale : 46/208 (22.12%), for a total net profit of 9.9290
#
# At day 89 :	price_t = 0.8421, with estimated purchase probability = 0.1471
# 		my valuation = 0.1239, won 90/10000 auctions, with a mean bid of 0.0577
# 		we sold 13/90 (14.44%) products, for a total net profit of 5.7559
# 		clairvoyant sale : 29/194 (14.95%), for a total net profit of 8.0349
#
# At day 90 :	price_t = 0.5263, with estimated purchase probability = 0.3247
# 		my valuation = 0.1709, won 138/10000 auctions, with a mean bid of 0.0827
# 		we sold 45/138 (32.61%) products, for a total net profit of 12.2660
# 		clairvoyant sale : 85/271 (31.37%), for a total net profit of 14.9717
#
# At day 91 :	price_t = 0.3158, with estimated purchase probability = 0.4749
# 		my valuation = 0.1500, won 101/10000 auctions, with a mean bid of 0.0751
# 		we sold 48/101 (47.52%) products, for a total net profit of 7.5713
# 		clairvoyant sale : 96/208 (46.15%), for a total net profit of 9.9090
#
# At day 92 :	price_t = 0.4737, with estimated purchase probability = 0.3605
# 		my valuation = 0.1708, won 117/10000 auctions, with a mean bid of 0.0810
# 		we sold 32/117 (27.35%) products, for a total net profit of 5.6773
# 		clairvoyant sale : 89/256 (34.77%), for a total net profit of 13.4783
#
# At day 93 :	price_t = 0.1053, with estimated purchase probability = 0.6657
# 		my valuation = 0.0701, won 33/10000 auctions, with a mean bid of 0.0412
# 		we sold 20/33 (60.61%) products, for a total net profit of 0.7471
# 		clairvoyant sale : 32/52 (61.54%), for a total net profit of 1.0057
#
# At day 94 :	price_t = 0.5789, with estimated purchase probability = 0.2881
# 		my valuation = 0.1668, won 136/10000 auctions, with a mean bid of 0.0781
# 		we sold 34/136 (25.00%) products, for a total net profit of 9.0652
# 		clairvoyant sale : 72/259 (27.80%), for a total net profit of 14.4588
#
# At day 95 :	price_t = 0.1579, with estimated purchase probability = 0.6099
# 		my valuation = 0.0963, won 48/10000 auctions, with a mean bid of 0.0443
# 		we sold 30/48 (62.50%) products, for a total net profit of 2.6128
# 		clairvoyant sale : 53/92 (57.61%), for a total net profit of 2.8099
#
# At day 96 :	price_t = 0.8947, with estimated purchase probability = 0.1338
# 		my valuation = 0.1197, won 81/10000 auctions, with a mean bid of 0.0577
# 		we sold 8/81 (9.88%) products, for a total net profit of 2.4877
# 		clairvoyant sale : 20/157 (12.74%), for a total net profit of 5.8154
#
# At day 97 :	price_t = 0.4211, with estimated purchase probability = 0.3950
# 		my valuation = 0.1663, won 137/10000 auctions, with a mean bid of 0.0755
# 		we sold 60/137 (43.80%) products, for a total net profit of 14.9131
# 		clairvoyant sale : 103/267 (38.58%), for a total net profit of 14.9093
#
# At day 98 :	price_t = 0.2105, with estimated purchase probability = 0.5623
# 		my valuation = 0.1184, won 69/10000 auctions, with a mean bid of 0.0554
# 		we sold 37/69 (53.62%) products, for a total net profit of 3.9650
# 		clairvoyant sale : 75/140 (53.57%), for a total net profit of 5.3534
#
# At day 99 :	price_t = 0.7368, with estimated purchase probability = 0.1917
# 		my valuation = 0.1413, won 103/10000 auctions, with a mean bid of 0.0686
# 		we sold 22/103 (21.36%) products, for a total net profit of 9.1492
# 		clairvoyant sale : 41/211 (19.43%), for a total net profit of 10.2234
#
# At day 100 :	price_t = 0.6316, with estimated purchase probability = 0.2542
# 		my valuation = 0.1605, won 114/10000 auctions, with a mean bid of 0.0776
# 		we sold 29/114 (25.44%) products, for a total net profit of 9.4739
# 		clairvoyant sale : 58/233 (24.89%), for a total net profit of 12.0952
#
# At day 101 :	price_t = 1.0000, with estimated purchase probability = 0.1313
# 		my valuation = 0.1313, won 90/10000 auctions, with a mean bid of 0.0653
# 		we sold 9/90 (10.00%) products, for a total net profit of 3.1201
# 		clairvoyant sale : 11/111 (9.91%), for a total net profit of 3.4024
#
# At day 102 :	price_t = 0.3684, with estimated purchase probability = 0.4336
# 		my valuation = 0.1598, won 119/10000 auctions, with a mean bid of 0.0733
# 		we sold 49/119 (41.18%) products, for a total net profit of 9.3307
# 		clairvoyant sale : 102/241 (42.32%), for a total net profit of 12.8479
#
# At day 103 :	price_t = 0.0526, with estimated purchase probability = 0.7173
# 		my valuation = 0.0378, won 16/10000 auctions, with a mean bid of 0.0175
# 		we sold 11/16 (68.75%) products, for a total net profit of 0.2984
# 		clairvoyant sale : 15/24 (62.50%), for a total net profit of 0.2844
#
# At day 104 :	price_t = 0.9474, with estimated purchase probability = 0.1251
# 		my valuation = 0.1185, won 70/10000 auctions, with a mean bid of 0.0605
# 		we sold 5/70 (7.14%) products, for a total net profit of 0.5036
# 		clairvoyant sale : 14/127 (11.02%), for a total net profit of 3.8588
#
# At day 105 :	price_t = 0.2632, with estimated purchase probability = 0.5154
# 		my valuation = 0.1356, won 103/10000 auctions, with a mean bid of 0.0685
# 		we sold 53/103 (51.46%) products, for a total net profit of 6.8932
# 		clairvoyant sale : 97/193 (50.26%), for a total net profit of 8.2652
#
# At day 106 :	price_t = 0.7895, with estimated purchase probability = 0.1664
# 		my valuation = 0.1314, won 82/10000 auctions, with a mean bid of 0.0658
# 		we sold 7/82 (8.54%) products, for a total net profit of 0.1341
# 		clairvoyant sale : 32/188 (17.02%), for a total net profit of 7.8154
#
# At day 107 :	price_t = 0.5263, with estimated purchase probability = 0.3231
# 		my valuation = 0.1701, won 150/10000 auctions, with a mean bid of 0.0791
# 		we sold 43/150 (28.67%) products, for a total net profit of 10.7714
# 		clairvoyant sale : 89/285 (31.23%), for a total net profit of 16.4871
#
# At day 108 :	price_t = 0.4737, with estimated purchase probability = 0.3583
# 		my valuation = 0.1697, won 129/10000 auctions, with a mean bid of 0.0819
# 		we sold 49/129 (37.98%) products, for a total net profit of 12.6425
# 		clairvoyant sale : 94/269 (34.94%), for a total net profit of 14.2496
#
# At day 109 :	price_t = 0.6842, with estimated purchase probability = 0.2200
# 		my valuation = 0.1506, won 116/10000 auctions, with a mean bid of 0.0764
# 		we sold 27/116 (23.28%) products, for a total net profit of 9.6161
# 		clairvoyant sale : 56/256 (21.88%), for a total net profit of 11.9487
#
# At day 110 :	price_t = 0.5789, with estimated purchase probability = 0.2876
# 		my valuation = 0.1665, won 133/10000 auctions, with a mean bid of 0.0788
# 		we sold 34/133 (25.56%) products, for a total net profit of 9.2097
# 		clairvoyant sale : 73/260 (28.08%), for a total net profit of 14.4435
#
# At day 111 :	price_t = 0.4211, with estimated purchase probability = 0.3952
# 		my valuation = 0.1664, won 142/10000 auctions, with a mean bid of 0.0747
# 		we sold 53/142 (37.32%) products, for a total net profit of 11.7147
# 		clairvoyant sale : 105/274 (38.32%), for a total net profit of 15.6620
#
# At day 112 :	price_t = 0.3158, with estimated purchase probability = 0.4729
# 		my valuation = 0.1494, won 119/10000 auctions, with a mean bid of 0.0682
# 		we sold 57/119 (47.90%) products, for a total net profit of 9.8881
# 		clairvoyant sale : 106/229 (46.29%), for a total net profit of 12.0654
#
# At day 113 :	price_t = 0.6316, with estimated purchase probability = 0.2523
# 		my valuation = 0.1594, won 137/10000 auctions, with a mean bid of 0.0727
# 		we sold 45/137 (32.85%) products, for a total net profit of 18.4553
# 		clairvoyant sale : 64/258 (24.81%), for a total net profit of 14.5563
#
# At day 114 :	price_t = 0.8421, with estimated purchase probability = 0.1437
# 		my valuation = 0.1210, won 65/10000 auctions, with a mean bid of 0.0585
# 		we sold 7/65 (10.77%) products, for a total net profit of 2.0917
# 		clairvoyant sale : 26/174 (14.94%), for a total net profit of 6.3998
#
# At day 115 :	price_t = 0.3684, with estimated purchase probability = 0.4333
# 		my valuation = 0.1596, won 115/10000 auctions, with a mean bid of 0.0734
# 		we sold 47/115 (40.87%) products, for a total net profit of 8.8724
# 		clairvoyant sale : 102/242 (42.15%), for a total net profit of 12.5216
#
# At day 116 :	price_t = 0.7368, with estimated purchase probability = 0.1906
# 		my valuation = 0.1404, won 73/10000 auctions, with a mean bid of 0.0643
# 		we sold 13/73 (17.81%) products, for a total net profit of 4.8871
# 		clairvoyant sale : 35/182 (19.23%), for a total net profit of 7.5052
#
# At day 117 :	price_t = 0.2105, with estimated purchase probability = 0.5598
# 		my valuation = 0.1178, won 66/10000 auctions, with a mean bid of 0.0575
# 		we sold 40/66 (60.61%) products, for a total net profit of 4.6242
# 		clairvoyant sale : 73/135 (54.07%), for a total net profit of 4.8783
#
# At day 118 :	price_t = 0.5263, with estimated purchase probability = 0.3228
# 		my valuation = 0.1699, won 146/10000 auctions, with a mean bid of 0.0811
# 		we sold 57/146 (39.04%) products, for a total net profit of 18.1553
# 		clairvoyant sale : 97/310 (31.29%), for a total net profit of 15.9837
#
# At day 119 :	price_t = 0.4737, with estimated purchase probability = 0.3600
# 		my valuation = 0.1705, won 134/10000 auctions, with a mean bid of 0.0843
# 		we sold 44/134 (32.84%) products, for a total net profit of 9.5420
# 		clairvoyant sale : 101/289 (34.95%), for a total net profit of 15.5074
#
# At day 120 :	price_t = 0.5789, with estimated purchase probability = 0.2883
# 		my valuation = 0.1669, won 124/10000 auctions, with a mean bid of 0.0803
# 		we sold 40/124 (32.26%) products, for a total net profit of 13.1990
# 		clairvoyant sale : 74/266 (27.82%), for a total net profit of 13.1748
#
# At day 121 :	price_t = 0.4211, with estimated purchase probability = 0.3963
# 		my valuation = 0.1669, won 120/10000 auctions, with a mean bid of 0.0795
# 		we sold 46/120 (38.33%) products, for a total net profit of 9.8274
# 		clairvoyant sale : 96/250 (38.40%), for a total net profit of 12.9880
#
# At day 122 :	price_t = 0.1579, with estimated purchase probability = 0.6090
# 		my valuation = 0.0962, won 52/10000 auctions, with a mean bid of 0.0465
# 		we sold 34/52 (65.38%) products, for a total net profit of 2.9483
# 		clairvoyant sale : 54/93 (58.06%), for a total net profit of 2.9708
#
# At day 123 :	price_t = 0.2632, with estimated purchase probability = 0.5166
# 		my valuation = 0.1360, won 85/10000 auctions, with a mean bid of 0.0645
# 		we sold 41/85 (48.24%) products, for a total net profit of 5.3040
# 		clairvoyant sale : 87/175 (49.71%), for a total net profit of 7.6431
#
# At day 124 :	price_t = 0.6842, with estimated purchase probability = 0.2216
# 		my valuation = 0.1516, won 113/10000 auctions, with a mean bid of 0.0719
# 		we sold 20/113 (17.70%) products, for a total net profit of 5.5588
# 		clairvoyant sale : 57/258 (22.09%), for a total net profit of 12.6135
#
# At day 125 :	price_t = 0.3158, with estimated purchase probability = 0.4734
# 		my valuation = 0.1495, won 116/10000 auctions, with a mean bid of 0.0713
# 		we sold 46/116 (39.66%) products, for a total net profit of 6.2552
# 		clairvoyant sale : 100/216 (46.30%), for a total net profit of 10.9003
#
# At day 126 :	price_t = 0.6316, with estimated purchase probability = 0.2538
# 		my valuation = 0.1603, won 129/10000 auctions, with a mean bid of 0.0756
# 		we sold 33/129 (25.58%) products, for a total net profit of 11.0854
# 		clairvoyant sale : 63/252 (25.00%), for a total net profit of 13.9535
#
# At day 127 :	price_t = 0.8947, with estimated purchase probability = 0.1272
# 		my valuation = 0.1138, won 58/10000 auctions, with a mean bid of 0.0550
# 		we sold 8/58 (13.79%) products, for a total net profit of 3.9660
# 		clairvoyant sale : 18/139 (12.95%), for a total net profit of 4.9154
#
# At day 128 :	price_t = 0.7895, with estimated purchase probability = 0.1641
# 		my valuation = 0.1295, won 76/10000 auctions, with a mean bid of 0.0663
# 		we sold 17/76 (22.37%) products, for a total net profit of 8.3798
# 		clairvoyant sale : 34/198 (17.17%), for a total net profit of 8.0844
#
# At day 129 :	price_t = 0.3684, with estimated purchase probability = 0.4317
# 		my valuation = 0.1591, won 140/10000 auctions, with a mean bid of 0.0748
# 		we sold 55/140 (39.29%) products, for a total net profit of 9.7928
# 		clairvoyant sale : 116/274 (42.34%), for a total net profit of 15.4294
#
# At day 130 :	price_t = 0.7368, with estimated purchase probability = 0.1923
# 		my valuation = 0.1417, won 85/10000 auctions, with a mean bid of 0.0665
# 		we sold 13/85 (15.29%) products, for a total net profit of 3.9258
# 		clairvoyant sale : 35/183 (19.13%), for a total net profit of 8.3371
#
# At day 131 :	price_t = 1.0000, with estimated purchase probability = 0.1243
# 		my valuation = 0.1243, won 75/10000 auctions, with a mean bid of 0.0605
# 		we sold 8/75 (10.67%) products, for a total net profit of 3.4598
# 		clairvoyant sale : 9/94 (9.57%), for a total net profit of 2.8825
#
# At day 132 :	price_t = 0.5263, with estimated purchase probability = 0.3223
# 		my valuation = 0.1696, won 133/10000 auctions, with a mean bid of 0.0791
# 		we sold 48/133 (36.09%) products, for a total net profit of 14.7394
# 		clairvoyant sale : 86/275 (31.27%), for a total net profit of 15.0598
#
# At day 133 :	price_t = 0.9474, with estimated purchase probability = 0.1202
# 		my valuation = 0.1139, won 66/10000 auctions, with a mean bid of 0.0586
# 		we sold 7/66 (10.61%) products, for a total net profit of 2.7659
# 		clairvoyant sale : 13/119 (10.92%), for a total net profit of 3.6457
#
# At day 134 :	price_t = 0.4737, with estimated purchase probability = 0.3581
# 		my valuation = 0.1696, won 130/10000 auctions, with a mean bid of 0.0866
# 		we sold 53/130 (40.77%) products, for a total net profit of 13.8419
# 		clairvoyant sale : 96/275 (34.91%), for a total net profit of 14.2295
#
# At day 135 :	price_t = 0.5789, with estimated purchase probability = 0.2892
# 		my valuation = 0.1674, won 130/10000 auctions, with a mean bid of 0.0793
# 		we sold 38/130 (29.23%) products, for a total net profit of 11.6892
# 		clairvoyant sale : 74/265 (27.92%), for a total net profit of 14.0371
#
# At day 136 :	price_t = 0.4211, with estimated purchase probability = 0.3949
# 		my valuation = 0.1663, won 124/10000 auctions, with a mean bid of 0.0812
# 		we sold 50/124 (40.32%) products, for a total net profit of 10.9897
# 		clairvoyant sale : 100/259 (38.61%), for a total net profit of 13.7754
#
# At day 137 :	price_t = 0.8421, with estimated purchase probability = 0.1427
# 		my valuation = 0.1202, won 78/10000 auctions, with a mean bid of 0.0612
# 		we sold 17/78 (21.79%) products, for a total net profit of 9.5397
# 		clairvoyant sale : 25/168 (14.88%), for a total net profit of 6.7951
#
# At day 138 :	price_t = 0.6842, with estimated purchase probability = 0.2233
# 		my valuation = 0.1528, won 81/10000 auctions, with a mean bid of 0.0734
# 		we sold 20/81 (24.69%) products, for a total net profit of 7.7385
# 		clairvoyant sale : 40/183 (21.86%), for a total net profit of 8.6727
#
# At day 139 :	price_t = 0.6316, with estimated purchase probability = 0.2561
# 		my valuation = 0.1617, won 113/10000 auctions, with a mean bid of 0.0768
# 		we sold 28/113 (24.78%) products, for a total net profit of 9.0062
# 		clairvoyant sale : 60/241 (24.90%), for a total net profit of 12.1381
#
# At day 140 :	price_t = 0.1053, with estimated purchase probability = 0.6613
# 		my valuation = 0.0696, won 22/10000 auctions, with a mean bid of 0.0297
# 		we sold 12/22 (54.55%) products, for a total net profit of 0.6092
# 		clairvoyant sale : 24/39 (61.54%), for a total net profit of 0.9567
#
# At day 141 :	price_t = 0.3158, with estimated purchase probability = 0.4711
# 		my valuation = 0.1488, won 89/10000 auctions, with a mean bid of 0.0713
# 		we sold 51/89 (57.30%) products, for a total net profit of 9.7636
# 		clairvoyant sale : 85/185 (45.95%), for a total net profit of 8.8478
#
# At day 142 :	price_t = 0.2632, with estimated purchase probability = 0.5147
# 		my valuation = 0.1355, won 87/10000 auctions, with a mean bid of 0.0647
# 		we sold 41/87 (47.13%) products, for a total net profit of 5.1647
# 		clairvoyant sale : 80/161 (49.69%), for a total net profit of 7.2242
#
# At day 143 :	price_t = 0.2105, with estimated purchase probability = 0.5578
# 		my valuation = 0.1174, won 66/10000 auctions, with a mean bid of 0.0579
# 		we sold 32/66 (48.48%) products, for a total net profit of 2.9154
# 		clairvoyant sale : 67/125 (53.60%), for a total net profit of 4.5286
#
# At day 144 :	price_t = 0.5263, with estimated purchase probability = 0.3251
# 		my valuation = 0.1711, won 138/10000 auctions, with a mean bid of 0.0813
# 		we sold 37/138 (26.81%) products, for a total net profit of 8.2527
# 		clairvoyant sale : 87/278 (31.29%), for a total net profit of 15.1512
#
# At day 145 :	price_t = 0.3684, with estimated purchase probability = 0.4320
# 		my valuation = 0.1592, won 107/10000 auctions, with a mean bid of 0.0748
# 		we sold 51/107 (47.66%) products, for a total net profit of 10.7890
# 		clairvoyant sale : 97/229 (42.36%), for a total net profit of 11.5527
#
# At day 146 :	price_t = 0.7895, with estimated purchase probability = 0.1660
# 		my valuation = 0.1311, won 98/10000 auctions, with a mean bid of 0.0653
# 		we sold 17/98 (17.35%) products, for a total net profit of 7.0222
# 		clairvoyant sale : 34/200 (17.00%), for a total net profit of 8.7655
#
# At day 147 :	price_t = 0.8947, with estimated purchase probability = 0.1292
# 		my valuation = 0.1156, won 55/10000 auctions, with a mean bid of 0.0539
# 		we sold 6/55 (10.91%) products, for a total net profit of 2.4056
# 		clairvoyant sale : 17/136 (12.50%), for a total net profit of 4.2750
#
# At day 148 :	price_t = 0.5789, with estimated purchase probability = 0.2897
# 		my valuation = 0.1677, won 154/10000 auctions, with a mean bid of 0.0794
# 		we sold 41/154 (26.62%) products, for a total net profit of 11.5034
# 		clairvoyant sale : 80/286 (27.97%), for a total net profit of 15.8457
#
# ...
# 		we sold 25/44 (56.82%) products, for a total net profit of 2.1125
# 		clairvoyant sale : 46/80 (57.50%), for a total net profit of 2.6751
#
# At day 316 :	price_t = 0.3684, with estimated purchase probability = 0.4280
# 		my valuation = 0.1577, won 112/10000 auctions, with a mean bid of 0.0797
# 		we sold 50/112 (44.64%) products, for a total net profit of 9.4992
# 		clairvoyant sale : 103/245 (42.04%), for a total net profit of 11.4924
#
# At day 317 :	price_t = 0.2105, with estimated purchase probability = 0.5507
# 		my valuation = 0.1159, won 64/10000 auctions, with a mean bid of 0.0581
# 		we sold 37/64 (57.81%) products, for a total net profit of 4.0700
# 		clairvoyant sale : 66/122 (54.10%), for a total net profit of 4.7195
#
# At day 318 :	price_t = 0.5789, with estimated purchase probability = 0.2853
# 		my valuation = 0.1652, won 135/10000 auctions, with a mean bid of 0.0762
# 		we sold 43/135 (31.85%) products, for a total net profit of 14.6115
# 		clairvoyant sale : 77/277 (27.80%), for a total net profit of 15.0355
#
# At day 319 :	price_t = 0.4211, with estimated purchase probability = 0.3910
# 		my valuation = 0.1646, won 140/10000 auctions, with a mean bid of 0.0831
# 		we sold 57/140 (40.71%) products, for a total net profit of 12.3669
# 		clairvoyant sale : 109/283 (38.52%), for a total net profit of 14.7206
#
# At day 320 :	price_t = 0.7895, with estimated purchase probability = 0.1685
# 		my valuation = 0.1331, won 85/10000 auctions, with a mean bid of 0.0645
# 		we sold 17/85 (20.00%) products, for a total net profit of 7.9377
# 		clairvoyant sale : 32/187 (17.11%), for a total net profit of 8.1531
#
# At day 321 :	price_t = 0.5263, with estimated purchase probability = 0.3197
# 		my valuation = 0.1683, won 157/10000 auctions, with a mean bid of 0.0760
# 		we sold 54/157 (34.39%) products, for a total net profit of 16.4930
# 		clairvoyant sale : 96/306 (31.37%), for a total net profit of 18.1490
#
# At day 322 :	price_t = 0.4737, with estimated purchase probability = 0.3550
# 		my valuation = 0.1682, won 136/10000 auctions, with a mean bid of 0.0797
# 		we sold 54/136 (39.71%) products, for a total net profit of 14.7368
# 		clairvoyant sale : 96/275 (34.91%), for a total net profit of 15.4246
#
# At day 323 :	price_t = 0.8421, with estimated purchase probability = 0.1474
# 		my valuation = 0.1242, won 79/10000 auctions, with a mean bid of 0.0588
# 		we sold 18/79 (22.78%) products, for a total net profit of 10.5148
# 		clairvoyant sale : 23/153 (15.03%), for a total net profit of 6.7478
#
# At day 324 :	price_t = 0.7368, with estimated purchase probability = 0.1948
# 		my valuation = 0.1436, won 90/10000 auctions, with a mean bid of 0.0653
# 		we sold 12/90 (13.33%) products, for a total net profit of 2.9677
# 		clairvoyant sale : 39/201 (19.40%), for a total net profit of 9.4403
#
# At day 325 :	price_t = 0.6842, with estimated purchase probability = 0.2224
# 		my valuation = 0.1522, won 111/10000 auctions, with a mean bid of 0.0719
# 		we sold 31/111 (27.93%) products, for a total net profit of 13.2344
# 		clairvoyant sale : 50/226 (22.12%), for a total net profit of 11.4228
#
# At day 326 :	price_t = 0.6316, with estimated purchase probability = 0.2537
# 		my valuation = 0.1602, won 124/10000 auctions, with a mean bid of 0.0805
# 		we sold 28/124 (22.58%) products, for a total net profit of 7.7000
# 		clairvoyant sale : 63/253 (24.90%), for a total net profit of 13.0420
#
# At day 327 :	price_t = 0.1053, with estimated purchase probability = 0.6424
# 		my valuation = 0.0676, won 24/10000 auctions, with a mean bid of 0.0346
# 		we sold 15/24 (62.50%) products, for a total net profit of 0.7480
# 		clairvoyant sale : 24/40 (60.00%), for a total net profit of 0.8028
#
# At day 328 :	price_t = 0.3158, with estimated purchase probability = 0.4678
# 		my valuation = 0.1477, won 114/10000 auctions, with a mean bid of 0.0753
# 		we sold 56/114 (49.12%) products, for a total net profit of 9.0946
# 		clairvoyant sale : 103/224 (45.98%), for a total net profit of 10.5558
#
# At day 329 :	price_t = 1.0000, with estimated purchase probability = 0.1129
# 		my valuation = 0.1129, won 66/10000 auctions, with a mean bid of 0.0543
# 		we sold 7/66 (10.61%) products, for a total net profit of 3.4164
# 		clairvoyant sale : 10/103 (9.71%), for a total net profit of 3.2908
#
# At day 330 :	price_t = 0.5789, with estimated purchase probability = 0.2860
# 		my valuation = 0.1656, won 130/10000 auctions, with a mean bid of 0.0791
# 		we sold 32/130 (24.62%) products, for a total net profit of 8.2451
# 		clairvoyant sale : 70/249 (28.11%), for a total net profit of 14.0253
#
# At day 331 :	price_t = 0.3684, with estimated purchase probability = 0.4290
# 		my valuation = 0.1580, won 118/10000 auctions, with a mean bid of 0.0768
# 		we sold 66/118 (55.93%) products, for a total net profit of 15.2503
# 		clairvoyant sale : 103/245 (42.04%), for a total net profit of 11.9676
#
# At day 332 :	price_t = 0.5263, with estimated purchase probability = 0.3203
# 		my valuation = 0.1686, won 123/10000 auctions, with a mean bid of 0.0799
# 		we sold 37/123 (30.08%) products, for a total net profit of 9.6420
# 		clairvoyant sale : 84/269 (31.23%), for a total net profit of 13.7989
#
# At day 333 :	price_t = 0.4211, with estimated purchase probability = 0.3923
# 		my valuation = 0.1652, won 141/10000 auctions, with a mean bid of 0.0756
# 		we sold 51/141 (36.17%) products, for a total net profit of 10.8117
# 		clairvoyant sale : 108/282 (38.30%), for a total net profit of 15.9047
#
# At day 334 :	price_t = 0.8947, with estimated purchase probability = 0.1314
# 		my valuation = 0.1175, won 81/10000 auctions, with a mean bid of 0.0608
# 		we sold 8/81 (9.88%) products, for a total net profit of 2.2291
# 		clairvoyant sale : 19/146 (13.01%), for a total net profit of 5.7945
#
# At day 335 :	price_t = 0.4737, with estimated purchase probability = 0.3555
# 		my valuation = 0.1684, won 130/10000 auctions, with a mean bid of 0.0807
# 		we sold 51/130 (39.23%) products, for a total net profit of 13.6627
# 		clairvoyant sale : 99/285 (34.74%), for a total net profit of 14.9511
#
# At day 336 :	price_t = 0.2632, with estimated purchase probability = 0.5096
# 		my valuation = 0.1341, won 93/10000 auctions, with a mean bid of 0.0687
# 		we sold 46/93 (49.46%) products, for a total net profit of 5.7203
# 		clairvoyant sale : 79/158 (50.00%), for a total net profit of 7.3750
#
# At day 337 :	price_t = 0.6316, with estimated purchase probability = 0.2531
# 		my valuation = 0.1598, won 121/10000 auctions, with a mean bid of 0.0826
# 		we sold 37/121 (30.58%) products, for a total net profit of 13.3726
# 		clairvoyant sale : 65/262 (24.81%), for a total net profit of 12.4183
#
# At day 338 :	price_t = 0.6842, with estimated purchase probability = 0.2226
# 		my valuation = 0.1523, won 123/10000 auctions, with a mean bid of 0.0728
# 		we sold 22/123 (17.89%) products, for a total net profit of 6.0978
# 		clairvoyant sale : 51/231 (22.08%), for a total net profit of 12.4511
#
# At day 339 :	price_t = 0.7895, with estimated purchase probability = 0.1688
# 		my valuation = 0.1333, won 88/10000 auctions, with a mean bid of 0.0645
# 		we sold 16/88 (18.18%) products, for a total net profit of 6.9549
# 		clairvoyant sale : 34/201 (16.92%), for a total net profit of 8.5928
#
# At day 340 :	price_t = 0.7368, with estimated purchase probability = 0.1940
# 		my valuation = 0.1430, won 95/10000 auctions, with a mean bid of 0.0650
# 		we sold 16/95 (16.84%) products, for a total net profit of 5.6145
# 		clairvoyant sale : 41/214 (19.16%), for a total net profit of 9.5713
#
# At day 341 :	price_t = 0.3158, with estimated purchase probability = 0.4689
# 		my valuation = 0.1481, won 104/10000 auctions, with a mean bid of 0.0739
# 		we sold 45/104 (43.27%) products, for a total net profit of 6.5238
# 		clairvoyant sale : 99/214 (46.26%), for a total net profit of 10.1851
#
# At day 342 :	price_t = 0.5789, with estimated purchase probability = 0.2860
# 		my valuation = 0.1656, won 125/10000 auctions, with a mean bid of 0.0768
# 		we sold 30/125 (24.00%) products, for a total net profit of 7.7648
# 		clairvoyant sale : 75/267 (28.09%), for a total net profit of 14.1710
#
# At day 343 :	price_t = 0.5263, with estimated purchase probability = 0.3200
# 		my valuation = 0.1684, won 140/10000 auctions, with a mean bid of 0.0785
# 		we sold 40/140 (28.57%) products, for a total net profit of 10.0629
# 		clairvoyant sale : 87/277 (31.41%), for a total net profit of 15.6928
#
# At day 344 :	price_t = 0.4211, with estimated purchase probability = 0.3918
# 		my valuation = 0.1650, won 126/10000 auctions, with a mean bid of 0.0775
# 		we sold 48/126 (38.10%) products, for a total net profit of 10.4434
# 		clairvoyant sale : 99/257 (38.52%), for a total net profit of 13.7295
#
# At day 345 :	price_t = 0.8421, with estimated purchase probability = 0.1476
# 		my valuation = 0.1243, won 81/10000 auctions, with a mean bid of 0.0648
# 		we sold 11/81 (13.58%) products, for a total net profit of 4.0183
# 		clairvoyant sale : 27/185 (14.59%), for a total net profit of 6.4815
#
# At day 346 :	price_t = 0.3684, with estimated purchase probability = 0.4294
# 		my valuation = 0.1582, won 113/10000 auctions, with a mean bid of 0.0764
# 		we sold 46/113 (40.71%) products, for a total net profit of 8.3156
# 		clairvoyant sale : 98/233 (42.06%), for a total net profit of 11.7768
#
# At day 347 :	price_t = 0.4737, with estimated purchase probability = 0.3550
# 		my valuation = 0.1682, won 150/10000 auctions, with a mean bid of 0.0804
# 		we sold 55/150 (36.67%) products, for a total net profit of 13.9919
# 		clairvoyant sale : 101/290 (34.83%), for a total net profit of 16.4529
#
# At day 348 :	price_t = 0.2105, with estimated purchase probability = 0.5513
# 		my valuation = 0.1161, won 47/10000 auctions, with a mean bid of 0.0605
# 		we sold 28/47 (59.57%) products, for a total net profit of 3.0492
# 		clairvoyant sale : 60/112 (53.57%), for a total net profit of 3.7057
#
# At day 349 :	price_t = 0.9474, with estimated purchase probability = 0.1187
# 		my valuation = 0.1124, won 53/10000 auctions, with a mean bid of 0.0546
# 		we sold 4/53 (7.55%) products, for a total net profit of 0.8959
# 		clairvoyant sale : 12/109 (11.01%), for a total net profit of 3.3575
#
# At day 350 :	price_t = 0.1579, with estimated purchase probability = 0.5962
# 		my valuation = 0.0941, won 39/10000 auctions, with a mean bid of 0.0435
# 		we sold 23/39 (58.97%) products, for a total net profit of 1.9369
# 		clairvoyant sale : 37/65 (56.92%), for a total net profit of 2.0878
#
# At day 351 :	price_t = 0.6316, with estimated purchase probability = 0.2526
# 		my valuation = 0.1595, won 129/10000 auctions, with a mean bid of 0.0760
# 		we sold 30/129 (23.26%) products, for a total net profit of 9.1385
# 		clairvoyant sale : 63/254 (24.80%), for a total net profit of 13.7098
#
# At day 352 :	price_t = 0.2632, with estimated purchase probability = 0.5095
# 		my valuation = 0.1341, won 86/10000 auctions, with a mean bid of 0.0689
# 		we sold 52/86 (60.47%) products, for a total net profit of 7.7593
# 		clairvoyant sale : 85/170 (50.00%), for a total net profit of 6.9529
#
# At day 353 :	price_t = 0.4211, with estimated purchase probability = 0.3921
# 		my valuation = 0.1651, won 114/10000 auctions, with a mean bid of 0.0822
# 		we sold 36/114 (31.58%) products, for a total net profit of 5.7861
# 		clairvoyant sale : 98/255 (38.43%), for a total net profit of 12.7548
#
# At day 354 :	price_t = 0.5263, with estimated purchase probability = 0.3191
# 		my valuation = 0.1679, won 129/10000 auctions, with a mean bid of 0.0774
# 		we sold 44/129 (34.11%) products, for a total net profit of 13.1706
# 		clairvoyant sale : 93/298 (31.21%), for a total net profit of 15.3847
#
# At day 355 :	price_t = 0.6842, with estimated purchase probability = 0.2216
# 		my valuation = 0.1516, won 121/10000 auctions, with a mean bid of 0.0729
# 		we sold 23/121 (19.01%) products, for a total net profit of 6.9165
# 		clairvoyant sale : 55/248 (22.18%), for a total net profit of 12.6266
#
# At day 356 :	price_t = 0.4737, with estimated purchase probability = 0.3548
# 		my valuation = 0.1680, won 131/10000 auctions, with a mean bid of 0.0798
# 		we sold 40/131 (30.53%) products, for a total net profit of 8.4958
# 		clairvoyant sale : 98/282 (34.75%), for a total net profit of 15.1635
#
# At day 357 :	price_t = 0.5789, with estimated purchase probability = 0.2845
# 		my valuation = 0.1647, won 144/10000 auctions, with a mean bid of 0.0794
# 		we sold 44/144 (30.56%) products, for a total net profit of 14.0460
# 		clairvoyant sale : 83/295 (28.14%), for a total net profit of 15.9575
#
# At day 358 :	price_t = 0.3684, with estimated purchase probability = 0.4295
# 		my valuation = 0.1582, won 93/10000 auctions, with a mean bid of 0.0821
# 		we sold 42/93 (45.16%) products, for a total net profit of 7.8381
# 		clairvoyant sale : 102/242 (42.15%), for a total net profit of 10.3690
#
# At day 359 :	price_t = 0.3158, with estimated purchase probability = 0.4692
# 		my valuation = 0.1482, won 88/10000 auctions, with a mean bid of 0.0707
# 		we sold 43/88 (48.86%) products, for a total net profit of 7.3550
# 		clairvoyant sale : 82/179 (45.81%), for a total net profit of 8.5331
#
# At day 360 :	price_t = 0.7368, with estimated purchase probability = 0.1932
# 		my valuation = 0.1424, won 107/10000 auctions, with a mean bid of 0.0678
# 		we sold 21/107 (19.63%) products, for a total net profit of 8.2204
# 		clairvoyant sale : 43/221 (19.46%), for a total net profit of 10.7554
#
# At day 361 :	price_t = 0.7895, with estimated purchase probability = 0.1684
# 		my valuation = 0.1330, won 81/10000 auctions, with a mean bid of 0.0630
# 		we sold 10/81 (12.35%) products, for a total net profit of 2.7953
# 		clairvoyant sale : 31/182 (17.03%), for a total net profit of 7.8668
#
# At day 362 :	price_t = 0.0526, with estimated purchase probability = 0.6901
# 		my valuation = 0.0363, won 6/10000 auctions, with a mean bid of 0.0234
# 		we sold 6/6 (100.00%) products, for a total net profit of 0.1751
# 		clairvoyant sale : 5/9 (55.56%), for a total net profit of 0.0277
#
# At day 363 :	price_t = 0.1053, with estimated purchase probability = 0.6555
# 		my valuation = 0.0690, won 34/10000 auctions, with a mean bid of 0.0303
# 		we sold 25/34 (73.53%) products, for a total net profit of 1.6013
# 		clairvoyant sale : 34/56 (60.71%), for a total net profit of 1.3478
#
# At day 364 :	price_t = 1.0000, with estimated purchase probability = 0.1120
# 		my valuation = 0.1120, won 56/10000 auctions, with a mean bid of 0.0564
# 		we sold 5/56 (8.93%) products, for a total net profit of 1.8409
# 		clairvoyant sale : 9/96 (9.38%), for a total net profit of 2.3870

# %%
clairprofit = np.array(clairvoyant_profits)
bidagentprofit = np.array(bidding_agent_profits)
print(clairprofit.shape)
print(bidagentprofit.shape)

cumulative_regret = np.cumsum(clairprofit[1:]-bidagentprofit)

plt.figure()
plt.plot(cumulative_regret, label="overall regret")
plt.legend()
plt.title('Cumulative Regret')
plt.xlabel('$days$')
plt.show();
# Out:
# (365,)
# (364,)

# %%
estimated_purchase_probability = (pricing_agent.mu_t + pricing_agent.beta(pricing_agent.t) * pricing_agent.sigma_t)
estimated_profits_per_customer = estimated_purchase_probability * pricing_agent.arms - pricing_agent.average_bidding_costs
ucbs = estimated_profits_per_customer * pricing_agent.average_customer_percentages

# Purchase probability, given by model and estimated by agent
fig, ax1 = plt.subplots()
ax1.plot(prices, estimated_purchase_probability, 'g-', label='Estimated probability')
ax1.plot(prices, conversion_probabilities, 'y-', label='Expected probability')
ax1.set_xlabel('Price')
ax1.set_ylabel('Purchase probability', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Profit curve
ax2 = ax1.twinx()
# ax2.plot(prices, pricing_agent.arms - pricing_agent.average_bidding_costs, 'o-', label='profit')
ax2.plot(prices, ucbs, 'r-', label='Estimated curve')
ax2.plot(prices, pricing_agent.average_customer_percentages*(conversion_probabilities*pricing_agent.arms - pricing_agent.average_bidding_costs), 'o-', label='Expected curve')
ax2.set_ylabel('Profit curve', color='r')
ax2.tick_params(axis='y', labelcolor='r')

ax1.legend(loc='center left')
ax2.legend(loc='center right')

plt.title('GPUCB - Final estimation')
plt.show()

# %%
# why first is higher than latter
# bidding_agent_profit = number_sale_t*p_t-np.sum(my_payments[0,:])
# clairvoyant_profit = clairvoyant_sales*p_t - np.sum(clairvoyant_payments)
print(f'At day {day} :\tprice_t = {p_t:.4f}, with estimated purchase probability = {purchase_probability_t:.4f}\
          \n\t\tmy valuation = {my_valuation_t:.4f}, won {int(n_customers_t)}/{n_users} auctions, with a mean bid of {scaled_payed_bid_per_user:.4f} \
          \n\t\twe sold {number_sale_t}/{int(n_customers_t)} ({number_sale_t/n_customers_t*100:.2f}%) products, for a total net profit of {bidding_agent_profit:.4f}\
          \n\t\tclairvoyant sale : {clairvoyant_sales}/{clairvoyant_customers} ({clairvoyant_sales/clairvoyant_customers*100:.2f}%), for a total net profit of {clairvoyant_profit:.4f}\n')

print(p_t*conversion_probabilities[pricing_agent.a_t])

print("Total profit :")
print(bidding_agent_profit)
print(clairvoyant_profit)

print("Total revenue :")
print(number_sale_t*p_t)
print(clairvoyant_sales*p_t)

print("Total payment :")
print(np.sum(my_payments[0,:]))
print(np.sum(clairvoyant_payments))

print("Total won auction :")
print(np.count_nonzero(my_payments[0,:]))
print(np.count_nonzero(clairvoyant_payments))

print("Mean payed bid :")
print(np.sum(my_payments[0,:])/np.count_nonzero(my_payments[0,:]))
print(np.sum(clairvoyant_payments)/np.count_nonzero(clairvoyant_payments))

print("agent")
for idx, el in enumerate(my_payments[0,:]!=0):
    if el and idx < 500:
        print(f'{idx} : {my_payments[0,:][idx]}')

print("clairvoyant")
for idx, el in enumerate(clairvoyant_payments!=0):
    if el and idx < 500:
        print(f'{idx} : {clairvoyant_payments[idx]}')

# At day 3 :	price_t = 0.5263, with estimated purchase probability = 0.35157362546534565          
# 		my valuation = 0.1850, won 150/10000 auctions, with a mean bid of 0.0896           
# 		we sold 48/150 (32.00%) products, for a total net profit of 11.8171          
# 		clairvoyant sale : 111/355 (31.27%), for a total net profit of 13.2371
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[34], line 7
#       1 # why first is higher than latter
#       2 # bidding_agent_profit = number_sale_t*p_t-np.sum(my_payments[0,:])
#       3 # clairvoyant_profit = clairvoyant_sales*p_t - np.sum(clairvoyant_payments)
#       4 print(f'At day {day} :\tprice_t = {p_t:.4f}, with estimated purchase probability = {purchase_probability_t:.4f}\
#       5           \n\t\tmy valuation = {my_valuation_t:.4f}, won {int(n_customers_t)}/{n_users} auctions, with a mean bid of {scaled_payed_bid_per_user:.4f} \
#       6           \n\t\twe sold {number_sale_t}/{int(n_customers_t)} ({number_sale_t/n_customers_t*100:.2f}%) products, for a total net profit of {bidding_agent_profit:.4f}\
# ----> 7           \n\t\tclairvoyant sale : {clairvoyant_sales}/{clairvoyant_customers} ({clairvoyant_sales/clairvoyant_customers*100:.2f}%), for a total net profit of {clairvoyant_profit:.4f}\n')
#       9 print(p_t*conversion_probabilities[pricing_agent.a_t])
#      11 print("Total profit :")
#
# ZeroDivisionError: division by zero

# %%
estimated_purchase_probability = (pricing_agent.mu_t + pricing_agent.beta(pricing_agent.t) * pricing_agent.sigma_t)
estimated_profits_per_customer = estimated_purchase_probability * (pricing_agent.arms - pricing_agent.average_bidding_costs)
ucbs = estimated_profits_per_customer * pricing_agent.average_customer_percentages

prices = np.linspace(scaled_min_price, scaled_max_price, price_discretization)
conversion_probabilities = StochasticPricingEnvironment.generate_probability(model, alpha, beta, prices)

fig, ax1 = plt.subplots()
ax1.plot(prices, estimated_purchase_probability, 'g-', label='Estimated probability')
ax1.plot(prices, conversion_probabilities, 'y-', label='Expected probability')
ax1.set_xlabel('Price')
ax1.set_ylabel('Purchase probability', color='g')
ax1.tick_params(axis='y', labelcolor='g')

ax2 = ax1.twinx()
# ax2.plot(prices, pricing_agent.arms - pricing_agent.average_bidding_costs, 'o-', label='profit')
ax2.plot(prices, ucbs, 'r-', label='Estimated curve')
ax2.plot(prices, conversion_probabilities*(pricing_agent.arms - pricing_agent.average_bidding_costs)*pricing_agent.average_customer_percentages, 'o-', label='Expected curve')
ax2.set_ylabel('Profit curve', color='r')
ax2.tick_params(axis='y', labelcolor='r')

ax1.legend(loc='center left')
ax2.legend(loc='upper right')

plt.title('GPUCB - Final estimation')
plt.show()

# %%
estimated_purchase_probability = (pricing_agent.mu_t + pricing_agent.beta(pricing_agent.t) * pricing_agent.sigma_t)
ucbs = estimated_purchase_probability * (pricing_agent.arms - pricing_agent.average_bidding_costs)

prices = np.linspace(scaled_min_price, scaled_max_price, price_discretization)
conversion_probabilities = StochasticPricingEnvironment.generate_probability(model, alpha, beta, prices)

fig, ax1 = plt.subplots()
ax1.plot(prices, estimated_purchase_probability, 'g-', label='Estimated probability')
ax1.plot(prices, conversion_probabilities, 'y-', label='Expected probability')
ax1.set_xlabel('Price')
ax1.set_ylabel('Purchase probability', color='g')
ax1.tick_params(axis='y', labelcolor='g')

ax2 = ax1.twinx()
ax2.plot(prices, ucbs, 'r-', label='Estimated curve')
ax2.plot(prices, conversion_probabilities*prices, 'b-', label='Expected curve')
ax2.set_ylabel('Profit curve', color='r')
ax2.tick_params(axis='y', labelcolor='r')

ax1.legend(loc='center left')
ax2.legend(loc='upper right')

plt.title('GPUCB - Final estimation')
plt.show()

# %%
price_hist = pricing_agent.action_hist
profits = pricing_agent.reward_hist

gp = RBFGaussianProcess(scale=scale)
gp.fit(price_hist, profits)
mu, sigma = gp.predict(prices)
plt.scatter(price_hist, profits, label='Samples', color='C1')
plt.plot(prices, mu, label='Average Normalized Profit')
# plt.axvline(best_price, color='red',label='Optimal Price')
plt.fill_between(prices, mu-sigma, mu+sigma, alpha=0.3, label='Uncertainty', color='C0')
plt.title('GPUCB - Final estimated profit curve (normalized)')
plt.xlabel('Price')
plt.legend()
plt.show();

# %%
plt.figure()
plt.barh(np.arange(price_discretization), pricing_agent.N_pulls)
plt.ylabel('actions')
plt.xlabel('numer of pulls')
plt.title('Number of pulls for each action')
plt.show();

# %%
price_hist = pricing_agent.action_hist

plt.figure()
plt.scatter(np.arange(len(price_hist)), price_hist, s=2, label='Chosen price')
plt.xlabel('$t$')
plt.ylabel('$price_t$')
plt.title('Chosen price by pricing agent')
# plt.legend()
plt.show()

# %%
chosen_price, purchase_probability_t, average_bid_cost_t = pricing_agent.pull_arm()
print(chosen_price)
print(purchase_probability_t)
print(average_bid_cost_t)
# Out:
# 0.5263157894736842
# 0.3194088516074189
# 0.07743624236154473

# %%
def MinMaxScaler(original, min_x, max_x):
    return (original - min_x) / (max_x - min_x)

def MinMaxRescaler(scaled, min_x, max_x):
    return min_x + (max_x - min_x) * scaled

np.random.seed(2)

# product 
min_price, max_price = 10, 20
production_cost = 10
price_discretization = 8
payed_bid_per_user = 0
scaled_payed_bid_per_user = 0
scaled_min_price = MinMaxScaler(min_price, min_price, max_price)
scaled_max_price = MinMaxScaler(max_price, min_price, max_price)
scaled_cost = MinMaxScaler(production_cost, min_price, max_price)  # equals to scaled_min_price

# Pricing Environment and Agent
# Logistic model example
model='logistic'
alpha=0.8
beta=-3
scale=2
TotalDays = 365
pricing_env = StochasticPricingEnvironment(model, alpha, beta)
pricing_agent_2 = GPUCBAgent(TotalDays, scaled_min_price, scaled_max_price, discretization=price_discretization, scale=scale)
n_customers_t = 0        # to be determined every day after bidding
# for clairvoyant's use
prices = np.linspace(scaled_min_price, scaled_max_price, price_discretization)
conversion_probabilities = StochasticPricingEnvironment.generate_probability(model, alpha, beta, prices)


# Bidding Environment parameters
n_users = 10000
n_competitors = 2
ctrs = np.ones(n_competitors+1)
B = 100
auction = SecondPriceAuction(ctrs)
bidding_agent_profits = []
clairvoyant_profits = []

# Foreach day
for day in range(price_discretization*4):
    # pricing agent sets the price of the day
    p_t, purchase_probability_t, average_bid_cost_t = pricing_agent_2.pull_arm()

    # Bidding Environment
    bidding_env = UniformBiddingEnvironment(n_users, n_competitors, auction, seed=day)

    # Bidding Agents
    my_valuation_t = p_t*purchase_probability_t # equals to daily_set_price (which took into account the production cost)

    # Exploratory round to estimate the purchase probability of each price
    if(day == 0):
        my_valuation_t = scaled_max_price
    
    
    eta = 1/np.sqrt(n_users) # from theory
    agentMP = MultiplicativePacingAgent(valuation=my_valuation_t,
                                    budget=B,
                                    T=n_users, 
                                    eta=eta)
    # agentCURMP = ContinuousUpdatedRhoMPAgent(valuation=my_valuation_t,
    #                                 budget=B,
    #                                 T=n_users, 
    #                                 eta=eta)
    # agentUCB = UCBAgent(my_valuation_t, B, n_users, range=my_valuation_t/2)
    # agentNF = UCBNFAgent(my_valuation_t, B, n_users, range=my_valuation_t/2)
    # agentNF1 = UCBNFAgent(my_valuation_t, B, n_users, range=0.1)    # range works as the hyperparameter in this problem
    
    bidding_agents = {
        "Multiplicative Pacing": agentMP,
        # "Continuously updated Rho MP": agentCURMP,
        # "Plain UCB": agentUCB,
        # "UCB with negative feedback": agentNF,
        # "UCBNF with range 0.1" : agentNF1
    }

    utilities = np.zeros((len(bidding_agents), n_users))
    my_bids = np.zeros((len(bidding_agents), n_users))
    my_payments = np.zeros((len(bidding_agents), n_users))
    total_wins = np.zeros((len(bidding_agents)))
    bidding_agent_profit=0
    number_sale_t=0

    np.random.seed(day)
    for u in range(n_users):
        # bidding process
        for idx, (name, agent) in enumerate(bidding_agents.items()):
            my_bid = agent.bid()
            winners, m_t = bidding_env.round(u, my_bid)
            my_win = int(winners==n_competitors)
            f_t, c_t = (my_valuation_t-m_t)*my_win, m_t*my_win
            agent.update(f_t, c_t)
            utilities[idx,u] = f_t
            my_bids[idx,u] = my_bid
            my_payments[idx,u] = c_t
            total_wins[idx] += my_win
    if(total_wins[0] != 0):
        n_customers_t = total_wins[0]
        scaled_payed_bid_per_user = np.sum(my_payments[0,:]) / total_wins[0]
    
    
    # Update pricing agent
    # Exploratory round to estimate purchase probability
    if(day == 0):
        original_a_t = pricing_agent_2.a_t
        customers_per_price = int(n_customers_t / price_discretization)
        for idx, price in enumerate(pricing_agent_2.arms):
            sales_per_price = pricing_env.round(price, customers_per_price)
            pricing_agent_2.a_t = idx
            pricing_agent_2.update(sales_per_price, customers_per_price)
            # print(f'Price # {idx} : {price} with {sales_per_price}/{customers_per_price} sales')
        pricing_agent_2.a_t = original_a_t
    # Normal rounds
    else:
        number_sale_t = pricing_env.round(p_t, n_customers_t)
        pricing_agent_2.update(number_sale_t, n_customers_t, scaled_payed_bid_per_user, n_customers_t/n_users)
        bidding_agent_profit = number_sale_t*p_t-np.sum(my_payments[0,:])
        bidding_agent_profits.append(bidding_agent_profit)

    # Clairvoyant utilities
    clairvoyant_bids, clairvoyant_utilities, clairvoyant_payments = bidding_env.get_clairvoyant_truthful(B, p_t*conversion_probabilities[pricing_agent_2.a_t])
    clairvoyant_customers = np.count_nonzero(clairvoyant_bids)
    clairvoyant_sales =  int(clairvoyant_customers * conversion_probabilities[pricing_agent_2.a_t])
    clairvoyant_profit = clairvoyant_sales*p_t - np.sum(clairvoyant_payments)
    if(clairvoyant_profit <=0 and day>0):
        print("Total revenue :")
        print(number_sale_t*p_t)
        print(clairvoyant_sales*p_t)

        print("Total payment :")
        print(np.sum(my_payments[0,:]))
        print(np.sum(clairvoyant_payments))

        print("Total won auction :")
        print(np.count_nonzero(my_payments[0,:]))
        print(np.count_nonzero(clairvoyant_payments))

        print("Mean payed bid :")
        print(np.sum(my_payments[0,:])/np.count_nonzero(my_payments[0,:]))
        print(np.sum(clairvoyant_payments)/np.count_nonzero(clairvoyant_payments))
        break
    clairvoyant_profits.append(clairvoyant_profit)

    # logging
    if(n_customers_t == 0):
        n_customers_t=1
    if(clairvoyant_customers == 0):
        clairvoyant_customers=1
    print(f'At day {day} :\tprice_t = {p_t:.4f}, with estimated purchase probability = {purchase_probability_t:.4f}\
          \n\t\tmy valuation = {my_valuation_t:.4f}, won {int(n_customers_t)}/{n_users} auctions, with a mean bid of {scaled_payed_bid_per_user:.4f} \
          \n\t\twe sold {number_sale_t}/{int(n_customers_t)} ({number_sale_t/n_customers_t*100:.2f}%) products, for a total net profit of {bidding_agent_profit:.4f}\
          \n\t\tclairvoyant sale : {clairvoyant_sales}/{clairvoyant_customers} ({clairvoyant_sales/clairvoyant_customers*100:.2f}%), for a total net profit of {clairvoyant_profit:.4f}\n')
    n_customers_t=0
    clairvoyant_customers=0
# Out:
# At day 0 :	price_t = 0.0000, with estimated purchase probability = 1.0000
# 		my valuation = 1.0000, won 349/10000 auctions, with a mean bid of 0.2842
# 		we sold 0/349 (0.00%) products, for a total net profit of 0.0000
# 		clairvoyant sale : 0/1 (0.00%), for a total net profit of 0.0000
#
# At day 1 :	price_t = 1.0000, with estimated purchase probability = 0.1752
# 		my valuation = 0.1752, won 141/10000 auctions, with a mean bid of 0.0852
# 		we sold 13/141 (9.22%) products, for a total net profit of 0.9844
# 		clairvoyant sale : 9/95 (9.47%), for a total net profit of 2.4703
#
# At day 2 :	price_t = 0.5714, with estimated purchase probability = 0.3055
# 		my valuation = 0.1746, won 150/10000 auctions, with a mean bid of 0.0804
# 		we sold 35/150 (23.33%) products, for a total net profit of 7.9461
# 		clairvoyant sale : 80/283 (28.27%), for a total net profit of 14.9471
#
# At day 3 :	price_t = 0.4286, with estimated purchase probability = 0.3897
# 		my valuation = 0.1670, won 120/10000 auctions, with a mean bid of 0.0830
# 		we sold 47/120 (39.17%) products, for a total net profit of 10.1882
# 		clairvoyant sale : 102/269 (37.92%), for a total net profit of 13.5036
#
# At day 4 :	price_t = 0.7143, with estimated purchase probability = 0.2128
# 		my valuation = 0.1520, won 124/10000 auctions, with a mean bid of 0.0759
# 		we sold 34/124 (27.42%) products, for a total net profit of 14.8797
# 		clairvoyant sale : 49/239 (20.50%), for a total net profit of 11.5390
#
# At day 5 :	price_t = 0.8571, with estimated purchase probability = 0.1765
# 		my valuation = 0.1513, won 96/10000 auctions, with a mean bid of 0.0737
# 		we sold 11/96 (11.46%) products, for a total net profit of 2.3571
# 		clairvoyant sale : 20/142 (14.08%), for a total net profit of 5.2283
#
# At day 6 :	price_t = 0.2857, with estimated purchase probability = 0.5032
# 		my valuation = 0.1438, won 104/10000 auctions, with a mean bid of 0.0714
# 		we sold 39/104 (37.50%) products, for a total net profit of 3.7163
# 		clairvoyant sale : 92/191 (48.17%), for a total net profit of 8.6156
#
# At day 7 :	price_t = 0.1429, with estimated purchase probability = 0.5759
# 		my valuation = 0.0823, won 21/10000 auctions, with a mean bid of 0.0347
# 		we sold 16/21 (76.19%) products, for a total net profit of 1.5561
# 		clairvoyant sale : 37/63 (58.73%), for a total net profit of 1.5653
#
# At day 8 :	price_t = 0.5714, with estimated purchase probability = 0.2854
# 		my valuation = 0.1631, won 142/10000 auctions, with a mean bid of 0.0804
# 		we sold 45/142 (31.69%) products, for a total net profit of 14.3045
# 		clairvoyant sale : 78/275 (28.36%), for a total net profit of 15.0135
#
# At day 9 :	price_t = 0.4286, with estimated purchase probability = 0.3858
# 		my valuation = 0.1654, won 132/10000 auctions, with a mean bid of 0.0787
# 		we sold 45/132 (34.09%) products, for a total net profit of 8.9017
# 		clairvoyant sale : 108/284 (38.03%), for a total net profit of 15.0013
#
# At day 10 :	price_t = 0.7143, with estimated purchase probability = 0.2208
# 		my valuation = 0.1577, won 123/10000 auctions, with a mean bid of 0.0747
# 		we sold 29/123 (23.58%) products, for a total net profit of 11.5224
# 		clairvoyant sale : 48/236 (20.34%), for a total net profit of 11.1930
#
# At day 11 :	price_t = 0.8571, with estimated purchase probability = 0.1726
# 		my valuation = 0.1479, won 120/10000 auctions, with a mean bid of 0.0678
# 		we sold 14/120 (11.67%) products, for a total net profit of 3.8694
# 		clairvoyant sale : 23/165 (13.94%), for a total net profit of 6.5784
#
# At day 12 :	price_t = 0.2857, with estimated purchase probability = 0.4978
# 		my valuation = 0.1422, won 81/10000 auctions, with a mean bid of 0.0751
# 		we sold 36/81 (44.44%) products, for a total net profit of 4.2026
# 		clairvoyant sale : 85/177 (48.02%), for a total net profit of 7.2446
#
# At day 13 :	price_t = 1.0000, with estimated purchase probability = 0.1264
# 		my valuation = 0.1264, won 90/10000 auctions, with a mean bid of 0.0588
# 		we sold 11/90 (12.22%) products, for a total net profit of 5.7118
# 		clairvoyant sale : 11/117 (9.40%), for a total net profit of 3.3949
#
# At day 14 :	price_t = 0.5714, with estimated purchase probability = 0.2856
# 		my valuation = 0.1632, won 96/10000 auctions, with a mean bid of 0.0792
# 		we sold 28/96 (29.17%) products, for a total net profit of 8.3995
# 		clairvoyant sale : 70/245 (28.57%), for a total net profit of 11.7912
#
# At day 15 :	price_t = 0.4286, with estimated purchase probability = 0.3762
# 		my valuation = 0.1612, won 119/10000 auctions, with a mean bid of 0.0755
# 		we sold 31/119 (26.05%) products, for a total net profit of 4.3050
# 		clairvoyant sale : 103/271 (38.01%), for a total net profit of 14.5562
#
# At day 16 :	price_t = 0.7143, with estimated purchase probability = 0.2178
# 		my valuation = 0.1556, won 119/10000 auctions, with a mean bid of 0.0679
# 		we sold 21/119 (17.65%) products, for a total net profit of 6.9235
# 		clairvoyant sale : 45/220 (20.45%), for a total net profit of 11.3933
#
# At day 17 :	price_t = 0.1429, with estimated purchase probability = 0.6101
# 		my valuation = 0.0872, won 37/10000 auctions, with a mean bid of 0.0499
# 		we sold 24/37 (64.86%) products, for a total net profit of 1.5841
# 		clairvoyant sale : 39/67 (58.21%), for a total net profit of 1.6126
#
# At day 18 :	price_t = 0.8571, with estimated purchase probability = 0.1647
# 		my valuation = 0.1412, won 99/10000 auctions, with a mean bid of 0.0722
# 		we sold 16/99 (16.16%) products, for a total net profit of 6.5693
# 		clairvoyant sale : 23/163 (14.11%), for a total net profit of 5.6802
#
# At day 19 :	price_t = 0.2857, with estimated purchase probability = 0.4845
# 		my valuation = 0.1384, won 92/10000 auctions, with a mean bid of 0.0606
# 		we sold 40/92 (43.48%) products, for a total net profit of 5.8525
# 		clairvoyant sale : 99/204 (48.53%), for a total net profit of 9.7132
#
# At day 20 :	price_t = 1.0000, with estimated purchase probability = 0.1252
# 		my valuation = 0.1252, won 70/10000 auctions, with a mean bid of 0.0597
# 		we sold 7/70 (10.00%) products, for a total net profit of 2.8205
# 		clairvoyant sale : 9/93 (9.68%), for a total net profit of 2.8015
#
# At day 21 :	price_t = 0.7143, with estimated purchase probability = 0.2133
# 		my valuation = 0.1524, won 100/10000 auctions, with a mean bid of 0.0722
# 		we sold 14/100 (14.00%) products, for a total net profit of 2.7753
# 		clairvoyant sale : 46/226 (20.35%), for a total net profit of 9.8831
#
# At day 22 :	price_t = 0.4286, with estimated purchase probability = 0.3587
# 		my valuation = 0.1537, won 100/10000 auctions, with a mean bid of 0.0716
# 		we sold 38/100 (38.00%) products, for a total net profit of 9.1219
# 		clairvoyant sale : 100/265 (37.74%), for a total net profit of 13.5288
#
# At day 23 :	price_t = 0.5714, with estimated purchase probability = 0.2698
# 		my valuation = 0.1542, won 115/10000 auctions, with a mean bid of 0.0733
# 		we sold 39/115 (33.91%) products, for a total net profit of 13.8549
# 		clairvoyant sale : 77/270 (28.52%), for a total net profit of 14.5833
#
# At day 24 :	price_t = 0.2857, with estimated purchase probability = 0.4820
# 		my valuation = 0.1377, won 104/10000 auctions, with a mean bid of 0.0659
# 		we sold 52/104 (50.00%) products, for a total net profit of 8.0012
# 		clairvoyant sale : 106/219 (48.40%), for a total net profit of 10.0157
#
# At day 25 :	price_t = 0.8571, with estimated purchase probability = 0.1588
# 		my valuation = 0.1361, won 72/10000 auctions, with a mean bid of 0.0577
# 		we sold 14/72 (19.44%) products, for a total net profit of 7.8483
# 		clairvoyant sale : 21/147 (14.29%), for a total net profit of 5.9447
#
# At day 26 :	price_t = 0.5714, with estimated purchase probability = 0.2764
# 		my valuation = 0.1580, won 127/10000 auctions, with a mean bid of 0.0716
# 		we sold 38/127 (29.92%) products, for a total net profit of 12.6183
# 		clairvoyant sale : 80/280 (28.57%), for a total net profit of 15.8744
#
# At day 27 :	price_t = 0.4286, with estimated purchase probability = 0.3670
# 		my valuation = 0.1573, won 94/10000 auctions, with a mean bid of 0.0743
# 		we sold 36/94 (38.30%) products, for a total net profit of 8.4421
# 		clairvoyant sale : 88/232 (37.93%), for a total net profit of 12.3658
#
# At day 28 :	price_t = 0.1429, with estimated purchase probability = 0.6138
# 		my valuation = 0.0877, won 37/10000 auctions, with a mean bid of 0.0483
# 		we sold 20/37 (54.05%) products, for a total net profit of 1.0706
# 		clairvoyant sale : 43/74 (58.11%), for a total net profit of 1.7380
#
# At day 29 :	price_t = 0.7143, with estimated purchase probability = 0.2146
# 		my valuation = 0.1533, won 111/10000 auctions, with a mean bid of 0.0750
# 		we sold 28/111 (25.23%) products, for a total net profit of 11.6701
# 		clairvoyant sale : 43/211 (20.38%), for a total net profit of 9.7031
#
# At day 30 :	price_t = 1.0000, with estimated purchase probability = 0.1211
# 		my valuation = 0.1211, won 66/10000 auctions, with a mean bid of 0.0566
# 		we sold 7/66 (10.61%) products, for a total net profit of 3.2624
# 		clairvoyant sale : 10/101 (9.90%), for a total net profit of 3.3496
#
# At day 31 :	price_t = 0.8571, with estimated purchase probability = 0.1637
# 		my valuation = 0.1403, won 98/10000 auctions, with a mean bid of 0.0686
# 		we sold 12/98 (12.24%) products, for a total net profit of 3.5629
# 		clairvoyant sale : 25/173 (14.45%), for a total net profit of 6.7773

# %%
# 40 rounds

estimated_purchase_probability = (pricing_agent_2.mu_t + pricing_agent_2.beta(pricing_agent_2.t) * pricing_agent_2.sigma_t)
estimated_profits_per_customer = estimated_purchase_probability * pricing_agent_2.arms - pricing_agent_2.average_bidding_costs
ucbs = estimated_profits_per_customer * pricing_agent_2.average_customer_percentages

# Purchase probability, given by model and estimated by agent
fig, ax1 = plt.subplots()
ax1.plot(prices, estimated_purchase_probability, 'g-', label='Estimated probability')
ax1.plot(prices, conversion_probabilities, 'y-', label='Expected probability')
ax1.set_xlabel('Price')
ax1.set_ylabel('Purchase probability', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Profit curve
ax2 = ax1.twinx()
# ax2.plot(prices, pricing_agent_2.arms - pricing_agent_2.average_bidding_costs, 'o-', label='profit')
ax2.plot(prices, ucbs, 'r-', label='Estimated curve')
ax2.plot(prices, pricing_agent_2.average_customer_percentages*(conversion_probabilities*pricing_agent_2.arms - pricing_agent_2.average_bidding_costs), 'o-', label='Expected curve')
ax2.set_ylabel('Profit curve', color='r')
ax2.tick_params(axis='y', labelcolor='r')

ax1.legend(loc='center left')
ax2.legend(loc='center right')

plt.title('GPUCB - Final estimation')
plt.show()

# %%
# 60 rounds

estimated_purchase_probability = (pricing_agent_2.mu_t + pricing_agent_2.beta(pricing_agent_2.t) * pricing_agent_2.sigma_t)
estimated_profits_per_customer = estimated_purchase_probability * pricing_agent_2.arms - pricing_agent_2.average_bidding_costs
ucbs = estimated_profits_per_customer * pricing_agent_2.average_customer_percentages

# Purchase probability, given by model and estimated by agent
fig, ax1 = plt.subplots()
ax1.plot(prices, estimated_purchase_probability, 'g-', label='Estimated probability')
ax1.plot(prices, conversion_probabilities, 'y-', label='Expected probability')
ax1.set_xlabel('Price')
ax1.set_ylabel('Purchase probability', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Profit curve
ax2 = ax1.twinx()
# ax2.plot(prices, pricing_agent_2.arms - pricing_agent_2.average_bidding_costs, 'o-', label='profit')
ax2.plot(prices, ucbs, 'r-', label='Estimated curve')
ax2.plot(prices, pricing_agent_2.average_customer_percentages*(conversion_probabilities*pricing_agent_2.arms - pricing_agent_2.average_bidding_costs), 'o-', label='Expected curve')
ax2.set_ylabel('Profit curve', color='r')
ax2.tick_params(axis='y', labelcolor='r')

ax1.legend(loc='center left')
ax2.legend(loc='center right')

plt.title('GPUCB - Final estimation')
plt.show()

# %%
# 80 rounds

estimated_purchase_probability = (pricing_agent_2.mu_t + pricing_agent_2.beta(pricing_agent_2.t) * pricing_agent_2.sigma_t)
estimated_profits_per_customer = estimated_purchase_probability * pricing_agent_2.arms - pricing_agent_2.average_bidding_costs
ucbs = estimated_profits_per_customer * pricing_agent_2.average_customer_percentages

# Purchase probability, given by model and estimated by agent
fig, ax1 = plt.subplots()
ax1.plot(prices, estimated_purchase_probability, 'g-', label='Estimated probability')
ax1.plot(prices, conversion_probabilities, 'y-', label='Expected probability')
ax1.set_xlabel('Price')
ax1.set_ylabel('Purchase probability', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Profit curve
ax2 = ax1.twinx()
# ax2.plot(prices, pricing_agent_2.arms - pricing_agent_2.average_bidding_costs, 'o-', label='profit')
ax2.plot(prices, ucbs, 'r-', label='Estimated curve')
ax2.plot(prices, pricing_agent_2.average_customer_percentages*(conversion_probabilities*pricing_agent_2.arms - pricing_agent_2.average_bidding_costs), 'o-', label='Expected curve')
ax2.set_ylabel('Profit curve', color='r')
ax2.tick_params(axis='y', labelcolor='r')

ax1.legend(loc='center left')
ax2.legend(loc='center right')

plt.title('GPUCB - Final estimation')
plt.show()

# %%
def MinMaxScaler(original, min_x, max_x):
    return (original - min_x) / (max_x - min_x)

def MinMaxRescaler(scaled, min_x, max_x):
    return min_x + (max_x - min_x) * scaled

np.random.seed(2)

# product 
min_price, max_price = 10, 20
production_cost = 10
price_discretization = 20
payed_bid_per_user = 0
scaled_payed_bid_per_user = 0
scaled_min_price = MinMaxScaler(min_price, min_price, max_price)
scaled_max_price = MinMaxScaler(max_price, min_price, max_price)
scaled_cost = MinMaxScaler(production_cost, min_price, max_price)  # equals to scaled_min_price

# Pricing Environment and Agent
# Logistic model example
model='logistic'
alpha=0.8
beta=-3
scale=2
TotalDays = 365
pricing_env = StochasticPricingEnvironment(model, alpha, beta)
pricing_agent_3 = GPUCBAgent(TotalDays, scaled_min_price, scaled_max_price, discretization=price_discretization, scale=scale)
n_customers_t = 0        # to be determined every day after bidding
# for clairvoyant's use
prices = np.linspace(scaled_min_price, scaled_max_price, price_discretization)
conversion_probabilities = StochasticPricingEnvironment.generate_probability(model, alpha, beta, prices)


# Bidding Environment parameters
n_users = 10000
n_competitors = 2
ctrs = np.ones(n_competitors+1)
B = 100
auction = SecondPriceAuction(ctrs)
bidding_agent_profits = []
clairvoyant_profits = []

# Foreach day
for day in range(TotalDays):
    # pricing agent sets the price of the day
    p_t, purchase_probability_t, average_bid_cost_t = pricing_agent_3.pull_arm()

    # Bidding Environment
    bidding_env = UniformBiddingEnvironment(n_users, n_competitors, auction, seed=day)

    # Bidding Agents
    my_valuation_t = p_t*purchase_probability_t # equals to daily_set_price (which took into account the production cost)

    # Exploratory round to estimate the purchase probability of each price
    if(day == 0):
        my_valuation_t = scaled_max_price
    
    
    eta = 1/np.sqrt(n_users) # from theory
    agentMP = MultiplicativePacingAgent(valuation=my_valuation_t,
                                    budget=B,
                                    T=n_users, 
                                    eta=eta)
    # agentCURMP = ContinuousUpdatedRhoMPAgent(valuation=my_valuation_t,
    #                                 budget=B,
    #                                 T=n_users, 
    #                                 eta=eta)
    # agentUCB = UCBAgent(my_valuation_t, B, n_users, range=my_valuation_t/2)
    # agentNF = UCBNFAgent(my_valuation_t, B, n_users, range=my_valuation_t/2)
    # agentNF1 = UCBNFAgent(my_valuation_t, B, n_users, range=0.1)    # range works as the hyperparameter in this problem
    
    bidding_agents = {
        "Multiplicative Pacing": agentMP,
        # "Continuously updated Rho MP": agentCURMP,
        # "Plain UCB": agentUCB,
        # "UCB with negative feedback": agentNF,
        # "UCBNF with range 0.1" : agentNF1
    }

    utilities = np.zeros((len(bidding_agents), n_users))
    my_bids = np.zeros((len(bidding_agents), n_users))
    my_payments = np.zeros((len(bidding_agents), n_users))
    total_wins = np.zeros((len(bidding_agents)))
    bidding_agent_profit=0
    number_sale_t=0

    np.random.seed(day)
    for u in range(n_users):
        # bidding process
        for idx, (name, agent) in enumerate(bidding_agents.items()):
            my_bid = agent.bid()
            winners, m_t = bidding_env.round(u, my_bid)
            my_win = int(winners==n_competitors)
            f_t, c_t = (my_valuation_t-m_t)*my_win, m_t*my_win
            agent.update(f_t, c_t)
            utilities[idx,u] = f_t
            my_bids[idx,u] = my_bid
            my_payments[idx,u] = c_t
            total_wins[idx] += my_win
    if(total_wins[0] != 0):
        n_customers_t = total_wins[0]
        scaled_payed_bid_per_user = np.sum(my_payments[0,:]) / total_wins[0]
    
    
    # Update pricing agent
    # Exploratory round to estimate purchase probability
    if(day == 0):
        original_a_t = pricing_agent_3.a_t
        customers_per_price = int(n_customers_t / price_discretization)
        for idx, price in enumerate(pricing_agent_3.arms):
            sales_per_price = pricing_env.round(price, customers_per_price)
            pricing_agent_3.a_t = idx
            pricing_agent_3.update(sales_per_price, customers_per_price)
            # print(f'Price # {idx} : {price} with {sales_per_price}/{customers_per_price} sales')
        pricing_agent_3.a_t = original_a_t
    # Normal rounds
    else:
        number_sale_t = pricing_env.round(p_t, n_customers_t)
        pricing_agent_3.update(number_sale_t, n_customers_t, scaled_payed_bid_per_user, n_customers_t/n_users)
        bidding_agent_profit = number_sale_t*p_t-np.sum(my_payments[0,:])
        bidding_agent_profits.append(bidding_agent_profit)

    # Clairvoyant utilities
    clairvoyant_bids, clairvoyant_utilities, clairvoyant_payments = bidding_env.get_clairvoyant_truthful(B, p_t*conversion_probabilities[pricing_agent_3.a_t])
    clairvoyant_customers = np.count_nonzero(clairvoyant_bids)
    clairvoyant_sales =  int(clairvoyant_customers * conversion_probabilities[pricing_agent_3.a_t])
    clairvoyant_profit = clairvoyant_sales*p_t - np.sum(clairvoyant_payments)
    if(clairvoyant_profit <=0 and day>0):
        print("Total revenue :")
        print(number_sale_t*p_t)
        print(clairvoyant_sales*p_t)

        print("Total payment :")
        print(np.sum(my_payments[0,:]))
        print(np.sum(clairvoyant_payments))

        print("Total won auction :")
        print(np.count_nonzero(my_payments[0,:]))
        print(np.count_nonzero(clairvoyant_payments))

        print("Mean payed bid :")
        print(np.sum(my_payments[0,:])/np.count_nonzero(my_payments[0,:]))
        print(np.sum(clairvoyant_payments)/np.count_nonzero(clairvoyant_payments))
        break
    clairvoyant_profits.append(clairvoyant_profit)

    # logging
    # if(n_customers_t == 0):
    #     n_customers_t=1
    # if(clairvoyant_customers == 0):
    #     clairvoyant_customers=1
    # print(f'At day {day} :\tprice_t = {p_t:.4f}, with estimated purchase probability = {purchase_probability_t:.4f}\
    #       \n\t\tmy valuation = {my_valuation_t:.4f}, won {int(n_customers_t)}/{n_users} auctions, with a mean bid of {scaled_payed_bid_per_user:.4f} \
    #       \n\t\twe sold {number_sale_t}/{int(n_customers_t)} ({number_sale_t/n_customers_t*100:.2f}%) products, for a total net profit of {bidding_agent_profit:.4f}\
    #       \n\t\tclairvoyant sale : {clairvoyant_sales}/{clairvoyant_customers} ({clairvoyant_sales/clairvoyant_customers*100:.2f}%), for a total net profit of {clairvoyant_profit:.4f}\n')
    # n_customers_t=0
    # clairvoyant_customers=0
    

estimated_purchase_probability = (pricing_agent_3.mu_t + pricing_agent_3.beta(pricing_agent_3.t) * pricing_agent_3.sigma_t)
estimated_profits_per_customer = estimated_purchase_probability * pricing_agent_3.arms - pricing_agent_3.average_bidding_costs
ucbs = estimated_profits_per_customer * pricing_agent_3.average_customer_percentages

# Purchase probability, given by model and estimated by agent
fig, ax1 = plt.subplots()
ax1.plot(prices, estimated_purchase_probability, 'g-', label='Estimated probability')
ax1.plot(prices, conversion_probabilities, 'y-', label='Expected probability')
ax1.plot(prices, estimated_profits_per_customer, 'o-', label='estimated_profits_per_customer')
ax1.set_xlabel('Price')
ax1.set_ylabel('Purchase probability', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Profit curve
ax2 = ax1.twinx()
# ax2.plot(prices, pricing_agent_3.arms - pricing_agent_3.average_bidding_costs, 'o-', label='profit')
ax2.plot(prices, ucbs, 'r-', label='Estimated curve')
ax2.plot(prices, pricing_agent_3.average_customer_percentages*(conversion_probabilities*pricing_agent_3.arms - pricing_agent_3.average_bidding_costs), 'o-', label='Expected curve')
ax2.set_ylabel('Profit curve', color='r')
ax2.tick_params(axis='y', labelcolor='r')

ax1.legend(loc='center left')
ax2.legend(loc='center right')

plt.title('GPUCB - Final estimation')
plt.show()

price_hist = pricing_agent_3.action_hist
profits = pricing_agent_3.reward_hist

gp = RBFGaussianProcess(scale=scale)
gp.fit(price_hist, profits)
mu, sigma = gp.predict(prices)
plt.scatter(price_hist, profits, label='Samples', color='C1')
plt.plot(prices, mu, label='Average Normalized Profit')
# plt.axvline(best_price, color='red',label='Optimal Price')
plt.fill_between(prices, mu-sigma, mu+sigma, alpha=0.3, label='Uncertainty', color='C0')
plt.title('GPUCB - Final estimated profit curve (normalized)')
plt.xlabel('Price')
plt.legend()
plt.show();


plt.figure()
plt.barh(np.arange(price_discretization), pricing_agent_3.N_pulls)
plt.ylabel('actions')
plt.xlabel('numer of pulls')
plt.title('Number of pulls for each action')
plt.show();



price_hist = pricing_agent_3.action_hist

plt.figure()
plt.scatter(np.arange(len(price_hist)), price_hist, s=2, label='Chosen price')
plt.xlabel('$t$')
plt.ylabel('$price_t$')
plt.title('Chosen price by pricing agent')
# plt.legend()
plt.show()


clairprofit = np.array(clairvoyant_profits)
bidagentprofit = np.array(bidding_agent_profits)
print(clairprofit.shape)
print(bidagentprofit.shape)

cumulative_regret = np.cumsum(clairprofit[1:]-bidagentprofit)

plt.figure()
plt.plot(cumulative_regret, label="overall regret")
plt.legend()
plt.title('Cumulative Regret')
plt.xlabel('$days$')
plt.show();
# Out:
# (365,)
# (364,)

# %%
print(pricing_agent_3.average_customer_percentages)
print(pricing_agent_3.average_bidding_costs)

estimated_purchase_probability = (pricing_agent_3.mu_t + pricing_agent_3.beta(pricing_agent_3.t) * pricing_agent_3.sigma_t)
estimated_profits_per_customer = estimated_purchase_probability * pricing_agent_3.arms - pricing_agent_3.average_bidding_costs
ucbs = estimated_profits_per_customer * pricing_agent_3.average_customer_percentages

plt.figure()
plt.plot(prices[1:], estimated_purchase_probability[1:], 'g-', label='Estimated probability')
# plt.plot(prices[1:], conversion_probabilities, 'y-', label='Expected probability')
plt.plot(prices[1:], (estimated_purchase_probability * pricing_agent_3.arms)[1:],  label='probability*price')
plt.plot(prices[1:], pricing_agent_3.average_bidding_costs[1:], label='average_bidding_costs')
plt.plot(prices[1:], estimated_profits_per_customer[1:], 'o-', label='estimated_profits_per_customer')
plt.plot(prices[1:], pricing_agent_3.average_customer_percentages[1:], 'o-', label='average_customer_percentages')
plt.title('average_bidding_costs')
plt.xlabel('Price')
plt.legend()
plt.show();
# Out:
# [1.         0.08646973 0.04582532 0.03200406 0.02462817 0.02285172
#  0.01936452 0.01974725 0.01810928 0.01867828 0.01850475 0.01767338
#  0.01844829 0.01951132 0.02026999 0.02185981 0.02435752 0.02381937
#  0.02836964 0.028933  ]
# [0.         0.01432449 0.02914036 0.04145772 0.05254694 0.0608182
#  0.06746232 0.07230668 0.07457517 0.07576589 0.07490362 0.07235628
#  0.06999922 0.06498538 0.06189636 0.05716767 0.05270831 0.05272387
#  0.05449004 0.05898919]

# %%
def MinMaxScaler(original, min_x, max_x):
    return (original - min_x) / (max_x - min_x)

def MinMaxRescaler(scaled, min_x, max_x):
    return min_x + (max_x - min_x) * scaled

np.random.seed(2)

# product 
min_price, max_price = 10, 20
production_cost = 10
price_discretization = 20
payed_bid_per_user = 0
scaled_payed_bid_per_user = 0
scaled_min_price = MinMaxScaler(min_price, min_price, max_price)
scaled_max_price = MinMaxScaler(max_price, min_price, max_price)
scaled_cost = MinMaxScaler(production_cost, min_price, max_price)  # equals to scaled_min_price

# Pricing Environment and Agent
# Logistic model example
model='logistic'
alpha=0.8
beta=-3
scale=2
TotalDays = 365
pricing_env = StochasticPricingEnvironment(model, alpha, beta)
pricing_agent_3 = GPUCBAgent(TotalDays, scaled_min_price, scaled_max_price, discretization=price_discretization, scale=scale)
n_customers_t = 0        # to be determined every day after bidding
# for clairvoyant's use
prices = np.linspace(scaled_min_price, scaled_max_price, price_discretization)
conversion_probabilities = StochasticPricingEnvironment.generate_probability(model, alpha, beta, prices)


# Bidding Environment parameters
n_users = 10000
n_competitors = 2
ctrs = np.ones(n_competitors+1)
B = 100
auction = SecondPriceAuction(ctrs)
bidding_agent_profits = []
clairvoyant_profits = []

# Foreach day
for day in range(TotalDays):
    # pricing agent sets the price of the day
    p_t, purchase_probability_t, average_bid_cost_t = pricing_agent_3.pull_arm()

    # Bidding Environment
    bidding_env = UniformBiddingEnvironment(n_users, n_competitors, auction, seed=day)

    # Bidding Agents
    my_valuation_t = p_t*purchase_probability_t # equals to daily_set_price (which took into account the production cost)

    # Exploratory round to estimate the purchase probability of each price
    if(day == 0):
        my_valuation_t = scaled_max_price
    
    
    eta = 1/np.sqrt(n_users) # from theory
    agentMP = MultiplicativePacingAgent(valuation=my_valuation_t,
                                    budget=B,
                                    T=n_users, 
                                    eta=eta)
    # agentCURMP = ContinuousUpdatedRhoMPAgent(valuation=my_valuation_t,
    #                                 budget=B,
    #                                 T=n_users, 
    #                                 eta=eta)
    # agentUCB = UCBAgent(my_valuation_t, B, n_users, range=my_valuation_t/2)
    # agentNF = UCBNFAgent(my_valuation_t, B, n_users, range=my_valuation_t/2)
    # agentNF1 = UCBNFAgent(my_valuation_t, B, n_users, range=0.1)    # range works as the hyperparameter in this problem
    
    bidding_agents = {
        "Multiplicative Pacing": agentMP,
        # "Continuously updated Rho MP": agentCURMP,
        # "Plain UCB": agentUCB,
        # "UCB with negative feedback": agentNF,
        # "UCBNF with range 0.1" : agentNF1
    }

    utilities = np.zeros((len(bidding_agents), n_users))
    my_bids = np.zeros((len(bidding_agents), n_users))
    my_payments = np.zeros((len(bidding_agents), n_users))
    total_wins = np.zeros((len(bidding_agents)))
    bidding_agent_profit=0
    number_sale_t=0

    np.random.seed(day)
    for u in range(n_users):
        # bidding process
        for idx, (name, agent) in enumerate(bidding_agents.items()):
            my_bid = agent.bid()
            winners, m_t = bidding_env.round(u, my_bid)
            my_win = int(winners==n_competitors)
            f_t, c_t = (my_valuation_t-m_t)*my_win, m_t*my_win
            agent.update(f_t, c_t)
            utilities[idx,u] = f_t
            my_bids[idx,u] = my_bid
            my_payments[idx,u] = c_t
            total_wins[idx] += my_win
    if(total_wins[0] != 0):
        n_customers_t = total_wins[0]
        scaled_payed_bid_per_user = np.sum(my_payments[0,:]) / total_wins[0]
    
    
    # Update pricing agent
    # Exploratory round to estimate purchase probability
    if(day == 0):
        original_a_t = pricing_agent_3.a_t
        customers_per_price = int(n_customers_t / price_discretization)
        for idx, price in enumerate(pricing_agent_3.arms):
            sales_per_price = pricing_env.round(price, customers_per_price)
            pricing_agent_3.a_t = idx
            pricing_agent_3.update(sales_per_price, customers_per_price)
            # print(f'Price # {idx} : {price} with {sales_per_price}/{customers_per_price} sales')
        pricing_agent_3.a_t = original_a_t
    # Normal rounds
    else:
        number_sale_t = pricing_env.round(p_t, n_customers_t)
        pricing_agent_3.update(number_sale_t, n_customers_t, scaled_payed_bid_per_user, n_customers_t/n_users)
        bidding_agent_profit = number_sale_t*p_t-np.sum(my_payments[0,:])
        bidding_agent_profits.append(bidding_agent_profit)

    # Clairvoyant utilities
    clairvoyant_bids, clairvoyant_utilities, clairvoyant_payments = bidding_env.get_clairvoyant_truthful(B, p_t*conversion_probabilities[pricing_agent_3.a_t])
    clairvoyant_customers = np.count_nonzero(clairvoyant_bids)
    clairvoyant_sales =  int(clairvoyant_customers * conversion_probabilities[pricing_agent_3.a_t])
    clairvoyant_profit = clairvoyant_sales*p_t - np.sum(clairvoyant_payments)
    if(clairvoyant_profit <=0 and day>0):
        print("Total revenue :")
        print(number_sale_t*p_t)
        print(clairvoyant_sales*p_t)

        print("Total payment :")
        print(np.sum(my_payments[0,:]))
        print(np.sum(clairvoyant_payments))

        print("Total won auction :")
        print(np.count_nonzero(my_payments[0,:]))
        print(np.count_nonzero(clairvoyant_payments))

        print("Mean payed bid :")
        print(np.sum(my_payments[0,:])/np.count_nonzero(my_payments[0,:]))
        print(np.sum(clairvoyant_payments)/np.count_nonzero(clairvoyant_payments))
        break
    clairvoyant_profits.append(clairvoyant_profit)

    # logging
    # if(n_customers_t == 0):
    #     n_customers_t=1
    # if(clairvoyant_customers == 0):
    #     clairvoyant_customers=1
    # print(f'At day {day} :\tprice_t = {p_t:.4f}, with estimated purchase probability = {purchase_probability_t:.4f}\
    #       \n\t\tmy valuation = {my_valuation_t:.4f}, won {int(n_customers_t)}/{n_users} auctions, with a mean bid of {scaled_payed_bid_per_user:.4f} \
    #       \n\t\twe sold {number_sale_t}/{int(n_customers_t)} ({number_sale_t/n_customers_t*100:.2f}%) products, for a total net profit of {bidding_agent_profit:.4f}\
    #       \n\t\tclairvoyant sale : {clairvoyant_sales}/{clairvoyant_customers} ({clairvoyant_sales/clairvoyant_customers*100:.2f}%), for a total net profit of {clairvoyant_profit:.4f}\n')
    # n_customers_t=0
    # clairvoyant_customers=0
